# %% [markdown]
# # ResLos Figure 1

# %%
# !conda install -y -c anaconda scikit-learn
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.

# %%
import itertools

import numpy as np
from scipy.stats import multivariate_normal, norm
from sklearn.datasets import fetch_openml
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF
from sklearn.gaussian_process.kernels import ConstantKernel as C
from sklearn.model_selection import train_test_split

# %%
from matplotlib import pyplot as plt

# %matplotlib inline

# %%
def sample(x, f, noise_f):
    y = f(x)
    stddev_x = noise_f(x)
    noise = np.random.normal(0, stddev_x)
    y += noise

    return y, stddev_x


def sample_and_fit_gp(x, f, noise_f):
    y, stddev_x = sample(x, f, noise_f)
    gp = fit_gp(x, y, stddev_x)

    return gp, y, stddev_x


def fit_gp(x, y, std):
    x = np.asarray(x)
    y = np.asarray(y)
    std = np.asarray(std)

    #kernel = C(1.0, (1e-3, 1e3)) * RBF(1, (1e-2, 1e2))
    kernel = RBF(1, (1e-2, 1e2))
    # kernel = RBF(0.1, (1e-2, 1e2))
    # Instantiate a Gaussian Process model
    gp = GaussianProcessRegressor(kernel=kernel, alpha=std ** 2, n_restarts_optimizer=10)

    # Fit to data using Maximum Likelihood Estimation of the parameters
    gp.fit(x[:, None], y)

    return gp

# %%
def plot_stddev(x, y, sigma, axes=None, color="b", label="95% confidence interval"):
    if axes is None:
        axes = plt.gca()

    axes.fill(
        np.concatenate([x, x[::-1]]),
        np.concatenate([y - 1.9600 * sigma, (y + 1.9600 * sigma)[::-1]]),
        alpha=0.25,
        fc=color,
        ec="None",
        label=label,
    )

# %%
def plot_gp(gp, obs_x, obs_y, obs_stddev, x_min=-5, x_max=5, axes=None, color="b", show_obs=True):
    if axes is None:
        axes = plt.gca()

    obs_x = np.asarray(obs_x)
    obs_y = np.asarray(obs_y)

    # x_min = obs_x.min() - padding
    # x_max = obs_x.max() + padding

    axes.set_xlim(x_min, x_max)

    x = np.linspace(x_min, x_max, 1000)
    y, sigma = gp.predict(x[:, None], return_std=True)

    if show_obs:
        axes.errorbar(obs_x, obs_y, obs_stddev, fmt="rx", markersize=10, label=u"Training Data")
    axes.plot(x, y, "-", color=color, label=u"Prediction")

    plot_stddev(x, y, sigma, color=color)

    return x, y, sigma

# %%
from ipywidgets import interact, interactive, fixed, interact_manual

# %%
X = np.arange(-15, 15, 0.05)
#Y = np.arange(-2.5, 3.5, 0.05)

# %%
# Simple func that looks interesting

def f_generic(X, *, a=1, b=1,c=0):
    return a*X+np.cos(b*(X-c))

@interact(a=(-10,10,0.1), b=(-10,10,0.1), c=(-10,10,0.1))
def examine_f(a=1,b=1,c=0):
    plt.plot(X, f_generic(X,a=a,b=b,c=c))
# Out:
# interactive(children=(FloatSlider(value=1.0, description='a', max=10.0, min=-10.0), FloatSlider(value=1.0, des…

# %%
f_a=1
f_b=np.pi*3
f_c=-0.5

def f(X):
    return f_generic(X, a=f_a, b=f_b, c=f_c) * 5

plt.plot(X, f(X))

# %% [markdown]
# ## Data distribution

# %%
import numpy as np
import scipy.stats
import scipy

# %%
data_distribution = scipy.stats.norm(0, 0.25)
data_X = data_distribution.rvs(50)

# %%
plt.plot(X, f(X))
plt.scatter(data_X[::2], [0]*(len(data_X)//2))
plt.scatter(data_X[1::2], [0]*(len(data_X)//2), color="red")
plt.xlim(-2,2)
# Out:
# (-2.0, 2.0)

# %%
test_X = data_X[::2]
test_Y = f(test_X)

val_X = data_X[1::2]
val_Y = f(val_X)

# %%
val_gp = fit_gp(val_X, val_Y, std=0.001)

# %%
train_data_distribution = scipy.stats.norm(0, 1)
train_X = train_data_distribution.rvs(0)
train_Y = f(train_X)

# %%
more_train_X = train_data_distribution.rvs(100)
more_train_Y = f(more_train_X)

# %%
train_gp = fit_gp(train_X, train_Y, std=0.001)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-269-c8ed680392f5> in <module>
# ----> 1 train_gp = fit_gp(train_X, train_Y, std=0.001)
#
# <ipython-input-230-ba4bc6a62cdf> in fit_gp(x, y, std)
#      27
#      28     # Fit to data using Maximum Likelihood Estimation of the parameters
# ---> 29     gp.fit(x[:, None], y)
#      30
#      31     return gp
#
# ~/anaconda3/envs/active_learning/lib/python3.8/site-packages/sklearn/gaussian_process/_gpr.py in fit(self, X, y)
#     187
#     188         if self.kernel_.requires_vector_input:
# --> 189             X, y = self._validate_data(X, y, multi_output=True, y_numeric=True,
#     190                                        ensure_2d=True, dtype="numeric")
#     191         else:
#
# ~/anaconda3/envs/active_learning/lib/python3.8/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# --> 432                 X, y = check_X_y(X, y, **check_params)
#     433             out = X, y
#     434
#
# ~/anaconda3/envs/active_learning/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~/anaconda3/envs/active_learning/lib/python3.8/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     793         raise ValueError("y cannot be None")
#     794
# --> 795     X = check_array(X, accept_sparse=accept_sparse,
#     796                     accept_large_sparse=accept_large_sparse,
#     797                     dtype=dtype, order=order, copy=copy,
#
# ~/anaconda3/envs/active_learning/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~/anaconda3/envs/active_learning/lib/python3.8/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     648         n_samples = _num_samples(array)
#     649         if n_samples < ensure_min_samples:
# --> 650             raise ValueError("Found array with %d sample(s) (shape=%s) while a"
#     651                              " minimum of %d is required%s."
#     652                              % (n_samples, array.shape, ensure_min_samples,
#
# ValueError: Found array with 0 sample(s) (shape=(0, 1)) while a minimum of 1 is required.

# %%
def plot_gp_mean(gp, obs_x, obs_y, x_min=-2, x_max=2, axes=None, color="b", show_obs=True, label="Prediction", obs_label="Training Data"):
    if axes is None:
        axes = plt.gca()

    obs_x = np.asarray(obs_x)
    obs_y = np.asarray(obs_y)

    # x_min = obs_x.min() - padding
    # x_max = obs_x.max() + padding

    axes.set_xlim(x_min, x_max)

    x = np.linspace(x_min, x_max, 1000)
    y, sigma = gp.predict(x[:, None], return_std=True)

    if show_obs:
        axes.scatter(obs_x, obs_y, color=color, label=obs_label)
    axes.plot(x, y, "-", color=color, label=label)

    return x, y, sigma

# %%
f_Y = f(X)
plt.plot(X, f(X), label="Ground truth")
plot_gp_mean(val_gp, val_X, val_Y, color="C1", label="Irreducible Model", obs_label="Validation Data")
plot_gp_mean(train_gp, train_X, train_Y, color="C2", label="Model", obs_label="Training Data")
plt.legend()
plt.xlim(-2,2)
plt.ylim(-20,20)
# Out:
# (-20.0, 20.0)

# %%
val_means = val_gp.predict(X[:, None], return_std=False)
train_means = X*0 - 20#train_gp.predict(X[:, None], return_std=False)

def get_losses(X):
    val_means = val_gp.predict(X[:, None], return_std=False)
    train_means = train_gp.predict(X[:, None], return_std=False)
    irreducible_loss =  (val_means - f(X))**2
    loss = (train_means - f(X))**2
    reducible_loss = loss-irreducible_loss
    return loss, irreducible_loss, reducible_loss

# %%
irreducible_loss =  np.abs(val_means - f(X))
loss = np.abs(train_means - f(X))
reducible_loss = loss-irreducible_loss

# %%
plt.plot(X, loss, label="Loss")
plt.plot(X, irreducible_loss, label="Irreducible Loss")
#plt.fill_between(X, irreducible_loss, loss, label="Reducible Loss", color="C2", alpha=0.25)
plt.plot(X, reducible_loss, label="Reducible Loss", color="C2")
plt.legend()
plt.xlim(-15,15)
#plt.ylim(-20,20)
# Out:
# (-15.0, 15.0)

# %%
plt.subplots(nrows=2, figsize=(10,10*1.6))
plt.subplot(3,1,1)
f_Y = f(X)
plt.plot(X, f_Y, label="Ground truth")
plot_gp_mean(val_gp, val_X, val_Y, color="C1", label="Irreducible Model", obs_label="Validation Data")
#plot_gp_mean(train_gp, train_X, train_Y, color="C2", label="Model", obs_label="Already Trained Data")
plt.plot(X, train_means, color="C2", label="Model")
plt.scatter(more_train_X, more_train_Y, color="C3", label="Available Training Data", zorder=-1)
plt.legend()
plt.xlim(-2,2)
plt.ylim(-22,20)
plt.gca().yaxis.set_ticklabels([])
plt.gca().xaxis.set_ticklabels([])
plt.subplot(3,1,2)
dpdf = data_distribution.pdf(X)
#plt.fill_between(X, dpdf/np.max(dpdf)*2, edgecolor="black", hatch="||", linewidth=1, facecolor="white", label="Test Distribution", zorder=0)
plt.fill_between(X, dpdf/np.max(dpdf)*2, edgecolor="black", hatch="||", linewidth=1, facecolor="white", label="Test Distribution", zorder=0)
plt.legend()
plt.xlim(-2,2)
plt.subplot(3,1,3)
plt.plot(X, irreducible_loss, color="C3", label="Irreducible Loss")
#plt.fill_between(X, irreducible_loss, loss, label="Reducible Loss", color="C2", alpha=0.25)
plt.plot(X, loss, color="C1", label="Loss", linewidth=3)
plt.plot(X, reducible_loss, label="Reducible Loss", color="C2", linewidth=3)
plt.scatter(more_train_X, [0] * len(more_train_X), color="C3", label="Available Training Data")
plt.legend()
plt.xlim(-20,20)
#plt.ylim(-1000,6000)
plt.ylim(-40,40)
# Out:
# (-40.0, 40.0)

# %%
x = [0.]
y = [2.]
stddev = 0.1
gp = fit_gp(
    x,
    y,
    stddev,
)

x_val = [1]*1
y_val = 0.5 + np.random.randn(1)*0.1
gp_val_only = fit_gp(x_val, y_val, stddev)
gp_val = fit_gp(np.concatenate([x, x_val]), np.concatenate([y, y_val]), stddev)

plot_gp(gp, x, y, stddev, color="blue")
plot_gp(gp_val_only, x_val, y_val, stddev, color="red")
plot_gp(gp_val, np.concatenate([x, x_val]), np.concatenate([y, y_val]), stddev, color="green")

plt.show()

# %%
def BALD(gp: GaussianProcessRegressor, x, stddev):
    y_mean, y_stddev = gp.predict([[x]], return_std=True)

    bald_value = norm(scale=y_stddev+stddev).entropy() - norm(scale=stddev).entropy()
    
    return bald_value

# %%
bald_scores = [BALD(gp, x, stddev) for x in X]

# %%
plot_gp(gp, x, y, stddev)
plt.plot(X, bald_scores, c="g", label="BALD")

# %%
def EPIG(gp: GaussianProcessRegressor, x, x_e, stddev):
    Y_mean, cov = gp.predict([[x], [x_e]], return_cov=True)

    cov += np.diag([stddev, stddev])

    H_Y = norm(scale=cov[0, 0] ** 0.5).entropy()
    H_Y_e = norm(scale=cov[1, 1] ** 0.5).entropy()

    H_Y__Y_e = multivariate_normal(Y_mean, cov=cov).entropy()

    # print(H_Y, H_Y_e, H_Y__Y_e)

    epig_value = H_Y + H_Y_e - H_Y__Y_e

    return epig_value

# %%
x_e = -1
epig_scores = [EPIG(gp, x, x_e, stddev) for x in X]

# %%
def PPIG(gp: GaussianProcessRegressor, gp_val: GaussianProcessRegressor, x, Y, stddev):
    y_mean, y_std = gp.predict([[x]], return_std=True)
    y_val_mean, y_val_std = gp_val.predict([[x]], return_std=True)

    y_std += stddev
    y_val_std += stddev
      
    ppig_values = -norm(y_mean, scale=y_std).logpdf(Y) + norm(y_val_mean, scale=y_val_std).logpdf(Y) 
    
    return ppig_values

# %%
def PPIG_alternative(gp: GaussianProcessRegressor, x, Y, x_val, y_val, stddev):
    #print(x, x_val)
    Y_mean, y_cov = gp.predict([x, x_val], return_cov=True)
    
    y_cov += np.diag([stddev, stddev])
    
    H_Y = -norm(Y_mean[0], scale=y_cov[0, 0] ** 0.5).logpdf(Y)
    H_Y_val = -norm(Y_mean[1], scale=y_cov[1, 1] ** 0.5).logpdf(y_val[0])
    
    H_Y__Y_val = -multivariate_normal(Y_mean, cov=y_cov).logpdf([[y, y_val[0]] for y in Y])
          
    # -log p(y) + -log p(y_v) - -log p(y, y_v) = -log p(y) - (-log p(y, y_v) - -log p(y_v))
    # = -log p(y) - -log p(y | y_v)
    # = -log p(y_v) - -log p(y_v | y)
    ppig_values = H_Y + H_Y_val - H_Y__Y_val
    
    return ppig_values

# %%
ppig_scores = [PPIG_alternative(gp, [x], Y, x_val, y_val, stddev) for x in X]
np.min(ppig_scores), np.max(ppig_scores)
# Out:
# (-20.501006800370252, 1.025563881132219)

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable
import numpy as np

ax = plt.subplot()
im = ax.imshow(np.arange(100).reshape((10, 10)))

# create an axes on the right side of ax. The width of cax will be 5%
# of ax and the padding between cax and ax will be fixed at 0.05 inch.
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.05)

plt.colorbar(im, cax=cax)

# %%
ax = plt.subplot()

plot_gp(gp, x, y, stddev, color="red", axes=ax, x_min=-6, x_max=6)
plot_gp(gp_val, x+x_val, y+y_val, stddev, color="red", axes=ax, show_obs=False, x_min=-6, x_max=6)

ax.set_xlim([-3, 3])
ax.set_ylim([-2.5, 3.5])

c = ax.contourf(X, Y, np.transpose(np.asarray(ppig_scores)), cmap="viridis", levels=255)

ax.scatter(x_val, y_val, c="black", marker="x", s=100, label="Validation Data", zorder=6)

divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.05)

plt.colorbar(c, cax=cax)

#ax.legend(loc="center left", bbox_to_anchor=(1, 0.5))

# plt.plot(X, epig_scores, c="r", linewidth=2, label="EPIG")
# plt.plot(X, bald_scores, c="g", linewidth=2, label="BALD")


# plt.vlines([x_e], ymin=-4, ymax=4, colors="black", label="Evaluation Point")
# handles, labels = plt.gca().get_legend_handles_labels()
# hl = list(zip(handles, labels))
# hl = [
#     hl[1],
#     hl[2],
# ]
# print(labels)

# %%
ppig_approx_scores = [PPIG(gp, gp_val_only, x, Y, stddev) for x in X]
np.min(ppig_approx_scores), np.max(ppig_approx_scores)
# Out:
# (-104.69563940347474, 245.76935306232292)

# %%
ax = plt.subplot()

# plot_gp(gp, x, y, stddev, color="red", axes=ax, x_min=-6, x_max=6)
# plot_gp(gp_val,np.concatenate([x, x_val]), np.concatenate([y, y_val]), stddev, color="red", axes=ax, show_obs=False, x_min=-6, x_max=6)

ax.set_xlim([-3, 3])
ax.set_ylim([-2.5, 3.5])

c = ax.contourf(X, Y, np.transpose(np.asarray(ppig_approx_scores)), cmap="viridis", levels=255, vmin=-20, vmax=20)

ax.scatter(x_val, y_val, c="black", marker="x", s=100, label="Validation Data", zorder=6)

divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.05)

plt.colorbar(c, cax=cax)

#ax.legend(loc="center left", bbox_to_anchor=(1, 0.5))

# plt.plot(X, epig_scores, c="r", linewidth=2, label="EPIG")
# plt.plot(X, bald_scores, c="g", linewidth=2, label="BALD")


# plt.vlines([x_e], ymin=-4, ymax=4, colors="black", label="Evaluation Point")
# handles, labels = plt.gca().get_legend_handles_labels()
# hl = list(zip(handles, labels))
# hl = [
#     hl[1],
#     hl[2],
# ]
# print(labels)

# %%
plot_gp(gp, x, y, stddev)
plt.plot(X, epig_scores, c="r", linewidth=2, label="EPIG")
plt.plot(X, bald_scores, c="g", linewidth=2, label="BALD")
#plt.scatter([x_e], [0], c="black", marker="o")

plt.vlines([x_e], ymin=-4, ymax=4, colors="black", label="Evaluation Point")
handles, labels = plt.gca().get_legend_handles_labels()
hl = list(zip(handles, labels))
hl = [hl[1], hl[2], ]
print(labels)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.xlim([-2, 2])
plt.ylim([-2.5, 3.5])
# Out:
# ['Prediction', 'EPIG', 'BALD', '95% confidence interval', 'Evaluation Point', 'Training Data']
# (-2.5, 3.5)
