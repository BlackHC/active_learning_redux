# %% [markdown]
# # Repeated-MNIST: Visualization
# > Ignorance is strength

# %%
# hide
import blackhc.project.script
# Out:
# Appended /home/blackhc/PycharmProjects/bald-ical/src to paths
# Switched to directory /home/blackhc/PycharmProjects/bald-ical
# %load_ext autoreload
# %autoreload 2

# %%
import collections
import functools
import math
import os
import re
from collections import namedtuple
from dataclasses import dataclass
from typing import NamedTuple

import laaos
import pandas as pd
import seaborn as sns
import torch

# %%
# https://codereview.stackexchange.com/questions/85311/transform-snake-case-to-camelcase
def camel_case_name(snake_case_name):
    return re.sub("_([a-z])", lambda match: match.group(1).upper(), snake_case_name)


__namedtuples = {}


def to_namedtuple(obj, name):
    type_name = "_" + camel_case_name(name)
    if isinstance(obj, dict):
        keys = tuple(obj.keys())
        if keys in __namedtuples:
            nt = __namedtuples[keys]
        else:
            nt = namedtuple(type_name, keys)
            __namedtuples[keys] = nt
        return nt(*(to_namedtuple(v, k) for k, v in obj.items()))
    if isinstance(obj, list):
        item_type_name = type_name + "Item"
        return [to_namedtuple(item, item_type_name) for item in obj]
    if isinstance(obj, set):
        item_type_name = type_name + "Item"
        return {to_namedtuple(item, item_type_name) for item in obj}
    if isinstance(obj, tuple):
        item_type_name = type_name + "Item"
        return tuple(to_namedtuple(item, item_type_name) for item in obj)

    return obj


def get_any(d: dict):
    return next(iter(d.values()))


def handle_map_funcs(func_kv, func_k, func_v, default=None):
    if func_kv:
        assert func_k is None and func_v is None

        def inner(kv):
            return func_kv(*kv)

    elif func_k:
        assert func_v is None

        def inner(kv):
            return func_k(kv[0]), kv[1]

    elif func_v:

        def inner(kv):
            return kv[0], func_v(kv[1])

    else:
        return default
    return inner


def handle_unary_funcs(pred_kv, pred_k, pred_v, default=None):
    if pred_kv:
        assert pred_k is None and pred_v is None

        def inner(kv):
            return pred_kv(*kv)

    elif pred_k:
        assert pred_v is None

        def inner(kv):
            return pred_k(kv[0])

    elif pred_v:

        def inner(kv):
            return pred_v(kv[1])

    else:
        return default
    return inner


def map_dict(d: dict, *, kv=None, k=None, v=None):
    inner = handle_map_funcs(kv, k, v)
    return dict(map(inner, d.items()))


def filter_dict(d: dict, *, kv=None, k=None, v=None):
    inner_pred = handle_unary_funcs(kv, k, v)
    return dict(filter(inner_pred, d.items()))


def sort_dict(d: dict, *, reverse=False, kv=None, k=None, v=None):
    inner_key = handle_unary_funcs(kv, k, v, default=lambda ikv: ikv[0])
    return dict(sorted(d.items(), key=inner_key, reverse=reverse))


def groupby_dict(d: dict, *, key_kv=None, key_k=None, key_v=None, agg=None):
    inner_key = handle_unary_funcs(key_kv, key_k, key_v)

    grouped_by = {}
    for kv in d.items():
        new_key = inner_key(kv)
        if new_key not in grouped_by:
            grouped_by[new_key] = {}
        key, value = kv
        grouped_by[new_key][key] = value

    if agg is not None:
        return map_dict(grouped_by, v=agg)

    return grouped_by

# %%
def get_laaos_files(laaos_dir=None):
    if laaos_dir is None:
        laaos_dir = "./batchbald_redux/results"

    laaos_files = {}
    for root, dirs, files in os.walk(laaos_dir, topdown=False):
        for name in files:
            if not name.endswith(".py"):
                continue

            rel_path = os.path.join(root, name)
            result_name = rel_path[len(laaos_dir) :]
            abs_path = os.path.abspath(rel_path)
            laaos_files[result_name] = abs_path

    return laaos_files


def load_laaos_files(path=None, files=None, vanilla=False, tag=None, prefix=None):
    if files is None:
        files = get_laaos_files(path)

    stores = {}
    for name, path in files.items():

        def nan():
            pass

        store = laaos.safe_load(path, exposed_symbols=[nan, torch])
        store["actual_name"] = name
        store["actual_path"] = path
        store["tag"] = tag

        key = f"{prefix}{name}" if prefix is not None else name
        stores[key] = store

    if vanilla:
        return stores
    else:
        return map_dict(stores, v=functools.partial(to_namedtuple, name="Result"))

# %%
results = load_laaos_files("./results/stochacq_fig1_repeated_mnist/", vanilla=True)

# %%
get_any(results)
# Out:
# {'timestamp': 1650893669,
#  'cmdline': ['/auto/users/andsch/github/active_learning_redux/batchbald_redux/experiment_repeated_mnist.py',
#   '--id=305'],
#  'commit': 'ca77e9c2486b71251c4f325833de05edf48201de',
#  'github_url': 'ca77e9c2486b71251c4f325833de05edf48201de',
#  'experiment': '/auto/users/andsch/github/active_learning_redux/batchbald_redux/experiment_repeated_mnist.py',
#  'job_id': 305,
#  'worker_id': 305,
#  'num_workers': 840,
#  'config': {'seed': 2070,
#   'experiment_data_config': {'id_dataset_name': 'MNIST',
#    'id_repetitions': 2,
#    'initial_training_set_size': 20,
#    'validation_set_size': 4096,
#    'validation_split_random_state': 0,
#    'evaluation_set_size': 0,
#    'add_dataset_noise': True,
#    'ood_dataset_config': None},
#   'acquisition_size': 40,
#   'max_training_set': 300,
#   'max_training_epochs': 300,
#   'num_pool_samples': 100,
#   'num_validation_samples': 20,
#   'num_training_samples': 1,
#   'device': 'cuda',
#   'acquisition_function': 'batchbald_redux.acquisition_functions.StochasticBALD',
#   'train_eval_model': 'batchbald_redux.train_eval_model.TrainSelfDistillationEvalModel',
#   'model_trainer_factory': 'batchbald_redux.models.MnistModelTrainer',
#   'ensemble_size': 1,
#   'temperature': 1.0,
#   'coldness': 1.0,
#   'stochastic_mode': 'StochasticMode.Softrank',
#   'epig_bootstrap_type': 'BootstrapType.NO_BOOTSTRAP',
#   'epig_bootstrap_factor': 1.0,
#   'epig_dtype': torch.float64,
#   'disable_training_augmentations': False,
#   'cache_explicit_eval_model': False,
#   'resnet18_dropout_head': True},
#  'log': {},
#  'dataset_info': {'training': "('MNIST (Train, seed=0, 55904 samples)')x2 + 𝓝(0;σ=0.1)",
#   'test': "'MNIST (Test)'"},
#  'initial_training_set_indices': [47227,
#   11511,
#   18383,
#   41080,
#   32837,
#   24393,
#   23904,
#   11784,
#   20439,
#   35043,
#   27367,
#   30426,
#   32361,
#   26116,
#   24386,
#   4689,
#   44895,
#   24211,
#   17212,
#   3478],
#  'evaluation_set_indices': [],
#  'seed': 7363250666291718322,
#  'active_learning_steps': [{'training': {'epochs': [{'accuracy': 0.328125,
#       'crossentropy': 2.193615436553955},
#      {'accuracy': 0.442626953125, 'crossentropy': 2.0156731605529785},
#      {'accuracy': 0.515869140625, 'crossentropy': 2.21724271774292},
#      {'accuracy': 0.5390625, 'crossentropy': 2.272160053253174},
#      {'accuracy': 0.53759765625, 'crossentropy': 2.336921453475952},
#      {'accuracy': 0.536376953125, 'crossentropy': 2.4224801063537598},
#      {'accuracy': 0.525146484375, 'crossentropy': 2.4452807903289795},
#      {'accuracy': 0.540771484375, 'crossentropy': 2.4156084060668945},
#      {'accuracy': 0.544189453125, 'crossentropy': 2.490274667739868},
#      {'accuracy': 0.552734375, 'crossentropy': 2.452087640762329},
#      {'accuracy': 0.547607421875, 'crossentropy': 2.536649227142334},
#      {'accuracy': 0.530517578125, 'crossentropy': 2.702319622039795},
#      {'accuracy': 0.527587890625, 'crossentropy': 2.791930675506592},
#      {'accuracy': 0.529052734375, 'crossentropy': 2.628472089767456},
#      {'accuracy': 0.53759765625, 'crossentropy': 2.5536422729492188},
#      {'accuracy': 0.55615234375, 'crossentropy': 2.4660403728485107},
#      {'accuracy': 0.54150390625, 'crossentropy': 2.6310906410217285},
#      {'accuracy': 0.54052734375, 'crossentropy': 2.65089750289917},
#      {'accuracy': 0.540771484375, 'crossentropy': 2.697509527206421},
#      {'accuracy': 0.547607421875, 'crossentropy': 2.665795087814331},
#      {'accuracy': 0.551025390625, 'crossentropy': 2.687312602996826},
#      {'accuracy': 0.551025390625, 'crossentropy': 2.6448793411254883},
#      {'accuracy': 0.549072265625, 'crossentropy': 2.708123207092285},
#      {'accuracy': 0.548828125, 'crossentropy': 2.765001058578491},
#      {'accuracy': 0.546875, 'crossentropy': 2.844907283782959},
#      {'accuracy': 0.54736328125, 'crossentropy': 2.865499496459961},
#      {'accuracy': 0.546875, 'crossentropy': 2.742269277572632},
#      {'accuracy': 0.5537109375, 'crossentropy': 2.6441385746002197},
#      {'accuracy': 0.561767578125, 'crossentropy': 2.747953176498413},
#      {'accuracy': 0.5654296875, 'crossentropy': 2.587632656097412},
#      {'accuracy': 0.564697265625, 'crossentropy': 2.600234270095825},
#      {'accuracy': 0.560302734375, 'crossentropy': 2.6066160202026367},
#      {'accuracy': 0.553955078125, 'crossentropy': 2.722144365310669},
#      {'accuracy': 0.55224609375, 'crossentropy': 2.775975227355957},
#      {'accuracy': 0.552001953125, 'crossentropy': 2.827707529067993},
#      {'accuracy': 0.560302734375, 'crossentropy': 2.6448278427124023},
#      {'accuracy': 0.5498046875, 'crossentropy': 2.6121737957000732},
#      {'accuracy': 0.563232421875, 'crossentropy': 2.6255388259887695},
#      {'accuracy': 0.554443359375, 'crossentropy': 2.587935209274292},
#      {'accuracy': 0.55029296875, 'crossentropy': 2.591158866882324},
#      {'accuracy': 0.56591796875, 'crossentropy': 2.5825486183166504},
#      {'accuracy': 0.565185546875, 'crossentropy': 2.6991207599639893},
#      {'accuracy': 0.544677734375, 'crossentropy': 2.7319743633270264},
#      {'accuracy': 0.544189453125, 'crossentropy': 2.696136951446533},
#      {'accuracy': 0.56494140625, 'crossentropy': 2.5088794231414795},
#      {'accuracy': 0.55615234375, 'crossentropy': 2.5936946868896484},
#      {'accuracy': 0.555908203125, 'crossentropy': 2.6589272022247314},
#      {'accuracy': 0.547119140625, 'crossentropy': 2.6625728607177734},
#      {'accuracy': 0.53564453125, 'crossentropy': 2.7702627182006836},
#      {'accuracy': 0.551513671875, 'crossentropy': 2.7090682983398438},
#      {'accuracy': 0.554931640625, 'crossentropy': 2.65871000289917},
#      {'accuracy': 0.5546875, 'crossentropy': 2.6940762996673584},
#      {'accuracy': 0.553466796875, 'crossentropy': 2.539760112762451},
#      {'accuracy': 0.568359375, 'crossentropy': 2.568221092224121},
#      {'accuracy': 0.5595703125, 'crossentropy': 2.5106263160705566},
#      {'accuracy': 0.563232421875, 'crossentropy': 2.604557991027832},
#      {'accuracy': 0.54931640625, 'crossentropy': 2.767791748046875},
#      {'accuracy': 0.55419921875, 'crossentropy': 2.733447551727295},
#      {'accuracy': 0.548095703125, 'crossentropy': 2.780303955078125},
#      {'accuracy': 0.55078125, 'crossentropy': 2.653616189956665},
#      {'accuracy': 0.5634765625, 'crossentropy': 2.473858118057251},
#      {'accuracy': 0.55029296875, 'crossentropy': 2.557499408721924},
#      {'accuracy': 0.55810546875, 'crossentropy': 2.410426378250122},
#      {'accuracy': 0.5517578125, 'crossentropy': 2.669668436050415},
#      {'accuracy': 0.544677734375, 'crossentropy': 2.7677392959594727},
#      {'accuracy': 0.55029296875, 'crossentropy': 2.7271742820739746},
#      {'accuracy': 0.540771484375, 'crossentropy': 2.715000629425049},
#      {'accuracy': 0.54443359375, 'crossentropy': 2.785581350326538},
#      {'accuracy': 0.556396484375, 'crossentropy': 2.6945507526397705},
#      {'accuracy': 0.56494140625, 'crossentropy': 2.5397403240203857},
#      {'accuracy': 0.561279296875, 'crossentropy': 2.5304369926452637},
#      {'accuracy': 0.5517578125, 'crossentropy': 2.5654690265655518},
#      {'accuracy': 0.548583984375, 'crossentropy': 2.6775150299072266},
#      {'accuracy': 0.551513671875, 'crossentropy': 2.657115936279297}],
#     'best_epoch': 53},
#    'evaluation_metrics': {'accuracy': 0.5737,
#     'crossentropy': 2.1477386951446533},
#    'acquisition': {'indices': [['id', 32360],
#      ['id', 47018],
#      ['id', 25990],
#      ['id', 35263],
#      ['id', 34654],
#      ['id', 18942],
#      ['id', 2848],
#      ['id', 3428],
#      ['id', 53469],
#      ['id', 47298],
#      ['id', 41103],
#      ['id', 47019],
#      ['id', 52354],
#      ['id', 1110],
#      ['id', 15185],
#      ['id', 49878],
#      ['id', 36621],
#      ['id', 36038],
#      ['id', 33006],
#      ['id', 11855],
#      ['id', 49546],
#      ['id', 42982],
#      ['id', 33068],
#      ['id', 50572],
#      ['id', 23180],
#      ['id', 17675],
#      ['id', 19529],
#      ['id', 11885],
#      ['id', 49192],
#      ['id', 3151],
#      ['id', 35289],
#      ['id', 53128],
#      ['id', 35921],
#      ['id', 39359],
#      ['id', 27753],
#      ['id', 2248],
#      ['id', 13624],
#      ['id', 11036],
#      ['id', 26116],
#      ['id', 5851]],
#     'labels': [8,
#      0,
#      6,
#      7,
#      0,
#      0,
#      4,
#      0,
#      8,
#      0,
#      4,
#      1,
#      4,
#      9,
#      4,
#      6,
#      7,
#      4,
#      9,
#      5,
#      2,
#      9,
#      0,
#      7,
#      5,
#      8,
#      5,
#      2,
#      6,
#      5,
#      9,
#      6,
#      1,
#      3,
#      2,
#      7,
#      9,
#      9,
#      6,
#      7],
#     'scores': [2.297377429915974,
#      1.2669737197454682,
#      0.9060067276477279,
#      0.9042059482291691,
#      0.8911909938608895,
#      0.8090759532010332,
#      0.7415041726073985,
#      0.635512803517992,
#      0.6191130584155875,
#      0.4954047480542192,
#      0.48720390154773074,
#      0.3522139119378038,
#      0.3336943869714428,
#      0.32957796017791985,
#      0.3158715598796089,
#      0.22602238238436279,
#      0.206998568168121,
#      0.1997890398543012,
#      0.02511201130733376,
#      -0.05202307164661413,
#      -0.06238371337665782,
#      -0.16641395074875476,
#      -0.1962706484599801,
#      -0.2043458917359695,
#      -0.37242781650130885,
#      -0.4550284149695045,
#      -0.5885823396479943,
#      -0.6178381339079682,
#      -0.6451895270506949,
#      -0.6619410533853372,
#      -0.6802626589903182,
#      -0.7347692519533018,
#      -0.7503723001743801,
#      -0.757118596162428,
#      -0.7735539346345046,
#      -0.9156875928220618,
#      -1.0440637814124045,
#      -1.057419189320119,
#      -1.0704331399641833,
#      -1.2226082148620243]}},
#   {'training': {'epochs': [{'accuracy': 0.115234375,
#       'crossentropy': 2.4204280376434326},
#      {'accuracy': 0.439697265625, 'crossentropy': 1.742513656616211},
#      {'accuracy': 0.599853515625, 'crossentropy': 1.3012406826019287},
#      {'accuracy': 0.619873046875, 'crossentropy': 1.2555122375488281},
#      {'accuracy': 0.6259765625, 'crossentropy': 1.2807304859161377},
#      {'accuracy': 0.64453125, 'crossentropy': 1.2290689945220947},
#      {'accuracy': 0.628662109375, 'crossentropy': 1.3491383790969849},
#      {'accuracy': 0.6494140625, 'crossentropy': 1.290520429611206},
#      {'accuracy': 0.645751953125, 'crossentropy': 1.2890137434005737},
#      {'accuracy': 0.645263671875, 'crossentropy': 1.3503395318984985},
#      {'accuracy': 0.649169921875, 'crossentropy': 1.3916985988616943},
#      {'accuracy': 0.641357421875, 'crossentropy': 1.3407492637634277},
#      {'accuracy': 0.647705078125, 'crossentropy': 1.3203920125961304},
#      {'accuracy': 0.659423828125, 'crossentropy': 1.3476094007492065},
#      {'accuracy': 0.65234375, 'crossentropy': 1.4170238971710205},
#      {'accuracy': 0.651123046875, 'crossentropy': 1.3974385261535645},
#      {'accuracy': 0.640625, 'crossentropy': 1.4806101322174072},
#      {'accuracy': 0.6494140625, 'crossentropy': 1.476128101348877},
#      {'accuracy': 0.65087890625, 'crossentropy': 1.4473580121994019},
#      {'accuracy': 0.64404296875, 'crossentropy': 1.4914584159851074},
#      {'accuracy': 0.65576171875, 'crossentropy': 1.4363000392913818},
#      {'accuracy': 0.656494140625, 'crossentropy': 1.4348938465118408},
#      {'accuracy': 0.654296875, 'crossentropy': 1.4485251903533936},
#      {'accuracy': 0.642822265625, 'crossentropy': 1.5442875623703003},
#      {'accuracy': 0.65380859375, 'crossentropy': 1.4516632556915283},
#      {'accuracy': 0.6484375, 'crossentropy': 1.4735417366027832},
#      {'accuracy': 0.656005859375, 'crossentropy': 1.4227230548858643},
#      {'accuracy': 0.64404296875, 'crossentropy': 1.560381293296814},
#      {'accuracy': 0.647216796875, 'crossentropy': 1.6475945711135864},
#      {'accuracy': 0.648193359375, 'crossentropy': 1.5345709323883057},
#      {'accuracy': 0.658203125, 'crossentropy': 1.462909460067749},
#      {'accuracy': 0.6591796875, 'crossentropy': 1.4895273447036743},
#      {'accuracy': 0.64990234375, 'crossentropy': 1.6502426862716675},
#      {'accuracy': 0.644775390625, 'crossentropy': 1.6888656616210938}],
#     'best_epoch': 13},
#    'evaluation_metrics': {'accuracy': 0.6558,
#     'crossentropy': 1.4520822763442993},
#    'acquisition': {'indices': [['id', 52377],
#      ['id', 20303],
#      ['id', 36479],
#      ['id', 11813],
#      ['id', 16911],
#      ['id', 4474],
#      ['id', 47178],
#      ['id', 45045],
#      ['id', 20939],
#      ['id', 370],
#      ['id', 49059],
#      ['id', 21506],
#      ['id', 44392],
#      ['id', 36478],
#      ['id', 17527],
#      ['id', 16370],
#      ['id', 18266],
#      ['id', 43374],
#      ['id', 48440],
#      ['id', 54190],
#      ['id', 16806],
#      ['id', 44659],
#      ['id', 29410],
#      ['id', 49113],
#      ['id', 19320],
#      ['id', 10210],
#      ['id', 18433],
#      ['id', 52376],
#      ['id', 54891],
#      ['id', 55367],
#      ['id', 48269],
#      ['id', 51861],
#      ['id', 41165],
#      ['id', 45551],
#      ['id', 38581],
#      ['id', 12518],
#      ['id', 39457],
#      ['id', 12953],
#      ['id', 24423],
#      ['id', 39717]],
#     'labels': [9,
#      1,
#      7,
#      7,
#      6,
#      9,
#      2,
#      2,
#      6,
#      9,
#      2,
#      5,
#      7,
#      4,
#      1,
#      7,
#      7,
#      4,
#      1,
#      5,
#      5,
#      7,
#      0,
#      6,
#      6,
#      0,
#      5,
#      9,
#      2,
#      3,
#      8,
#      3,
#      6,
#      0,
#      4,
#      2,
#      0,
#      3,
#      8,
#      9],
#     'scores': [1.3854537431678842,
#      1.143054004131061,
#      1.0307503021784628,
#      1.0271037662160225,
#      0.9068028243479507,
#      0.6499559039160498,
#      0.3763079464006509,
#      0.12770233537836617,
#      -0.02374175890497998,
#      -0.13863747932715054,
#      -0.1427327573698136,
#      -0.16066710831172148,
#      -0.40191918332702237,
#      -0.4079704442803138,
#      -0.47857740617770794,
#      -0.5059022099616515,
#      -0.5896193199125035,
#      -0.684977026198716,
#      -0.8630875383354564,
#      -0.892442329164246,
#      -0.9127696080911241,
#      -0.9455795413329771,
#      -0.950708319329495,
#      -0.996881851840417,
#      -1.049065524543181,
#      -1.1234983170820563,
#      -1.1471072551115613,
#      -1.182193708099939,
#      -1.1922685350965718,
#      -1.244310751122045,
#      -1.2832777140246083,
#      -1.3002324716219782,
#      -1.3174278050116257,
#      -1.3205770320556152,
#      -1.3434165678825378,
#      -1.524487058906887,
#      -1.5476223456331804,
#      -1.5573403580493559,
#      -1.5737650952673254,
#      -1.6121008585328491]}},
#   {'training': {'epochs': [{'accuracy': 0.168701171875,
#       'crossentropy': 2.240196704864502},
#      {'accuracy': 0.416015625, 'crossentropy': 1.6183255910873413},
#      {'accuracy': 0.665283203125, 'crossentropy': 1.0695353746414185},
#      {'accuracy': 0.765869140625, 'crossentropy': 0.8197387456893921},
#      {'accuracy': 0.758544921875, 'crossentropy': 0.7503613233566284},
#      {'accuracy': 0.78515625, 'crossentropy': 0.6750490665435791},
#      {'accuracy': 0.803955078125, 'crossentropy': 0.6223199367523193},
#      {'accuracy': 0.812744140625, 'crossentropy': 0.611086368560791},
#      {'accuracy': 0.797607421875, 'crossentropy': 0.6337277889251709},
#      {'accuracy': 0.801513671875, 'crossentropy': 0.6318025588989258},
#      {'accuracy': 0.8076171875, 'crossentropy': 0.6246484518051147},
#      {'accuracy': 0.812744140625, 'crossentropy': 0.640478789806366},
#      {'accuracy': 0.80615234375, 'crossentropy': 0.6348945498466492},
#      {'accuracy': 0.817138671875, 'crossentropy': 0.596749484539032},
#      {'accuracy': 0.81982421875, 'crossentropy': 0.6278413534164429},
#      {'accuracy': 0.808349609375, 'crossentropy': 0.6294144988059998},
#      {'accuracy': 0.817138671875, 'crossentropy': 0.6219186782836914},
#      {'accuracy': 0.8154296875, 'crossentropy': 0.6107165813446045},
#      {'accuracy': 0.81201171875, 'crossentropy': 0.6278902292251587},
#      {'accuracy': 0.801513671875, 'crossentropy': 0.6814818978309631},
#      {'accuracy': 0.79833984375, 'crossentropy': 0.6595577597618103},
#      {'accuracy': 0.809814453125, 'crossentropy': 0.6579892039299011},
#      {'accuracy': 0.802001953125, 'crossentropy': 0.6769714951515198},
#      {'accuracy': 0.810546875, 'crossentropy': 0.6450256109237671},
#      {'accuracy': 0.81689453125, 'crossentropy': 0.658793032169342},
#      {'accuracy': 0.806884765625, 'crossentropy': 0.6875459551811218},
#      {'accuracy': 0.823486328125, 'crossentropy': 0.6299522519111633},
#      {'accuracy': 0.822265625, 'crossentropy': 0.615856409072876},
#      {'accuracy': 0.8251953125, 'crossentropy': 0.6154108047485352},
#      {'accuracy': 0.812744140625, 'crossentropy': 0.6485984325408936},
#      {'accuracy': 0.80419921875, 'crossentropy': 0.6652504205703735},
#      {'accuracy': 0.820068359375, 'crossentropy': 0.6346232891082764},
#      {'accuracy': 0.81884765625, 'crossentropy': 0.6567879319190979},
#      {'accuracy': 0.814208984375, 'crossentropy': 0.6794533729553223},
#      {'accuracy': 0.802734375, 'crossentropy': 0.7098117470741272},
#      {'accuracy': 0.8037109375, 'crossentropy': 0.7004499435424805},
#      {'accuracy': 0.810546875, 'crossentropy': 0.680813729763031},
#      {'accuracy': 0.81298828125, 'crossentropy': 0.6467945575714111},
#      {'accuracy': 0.807861328125, 'crossentropy': 0.6462025046348572},
#      {'accuracy': 0.8076171875, 'crossentropy': 0.682212233543396},
#      {'accuracy': 0.8154296875, 'crossentropy': 0.6541959047317505},
#      {'accuracy': 0.8203125, 'crossentropy': 0.6624587774276733},
#      {'accuracy': 0.79443359375, 'crossentropy': 0.7030255198478699},
#      {'accuracy': 0.8056640625, 'crossentropy': 0.6918127536773682},
#      {'accuracy': 0.792724609375, 'crossentropy': 0.7505825757980347},
#      {'accuracy': 0.802978515625, 'crossentropy': 0.696491539478302},
#      {'accuracy': 0.81298828125, 'crossentropy': 0.6361824870109558},
#      {'accuracy': 0.8017578125, 'crossentropy': 0.6605913043022156},
#      {'accuracy': 0.80419921875, 'crossentropy': 0.6897037029266357}],
#     'best_epoch': 28},
#    'evaluation_metrics': {'accuracy': 0.8291,
#     'crossentropy': 0.5525848269462585},
#    'acquisition': {'indices': [['id', 22004],
#      ['id', 611],
#      ['id', 32191],
#      ['id', 26952],
#      ['id', 32934],
#      ['id', 2559],
#      ['id', 47627],
#      ['id', 40974],
#      ['id', 31229],
#      ['id', 12380],
#      ['id', 53668],
#      ['id', 28356],
#      ['id', 41924],
#      ['id', 47314],
#      ['id', 28948],
#      ['id', 51311],
#      ['id', 35144],
#      ['id', 26768],
#      ['id', 17859],
#      ['id', 38905],
#      ['id', 47367],
#      ['id', 12694],
#      ['id', 26153],
#      ['id', 25108],
#      ['id', 52687],
#      ['id', 1428],
#      ['id', 50900],
#      ['id', 3557],
#      ['id', 36902],
#      ['id', 54962],
#      ['id', 15628],
#      ['id', 42315],
#      ['id', 24091],
#      ['id', 13925],
#      ['id', 50427],
#      ['id', 35145],
#      ['id', 26110],
#      ['id', 13536],
#      ['id', 5619],
#      ['id', 38487]],
#     'labels': [0,
#      8,
#      5,
#      5,
#      1,
#      8,
#      2,
#      5,
#      7,
#      5,
#      1,
#      6,
#      2,
#      9,
#      4,
#      7,
#      1,
#      6,
#      8,
#      0,
#      0,
#      0,
#      5,
#      7,
#      8,
#      2,
#      0,
#      3,
#      7,
#      5,
#      4,
#      0,
#      4,
#      6,
#      2,
#      1,
#      2,
#      6,
#      8,
#      7],
#     'scores': [2.5848427885002003,
#      1.7963044450952879,
#      1.6683056720184766,
#      1.6073061322550544,
#      1.5030896286674285,
#      1.2141072352101552,
#      0.4861456608090027,
#      0.2939535744938242,
#      0.2536907306978824,
#      0.06723641796554691,
#      0.04313304711494581,
#      -0.031935979081326726,
#      -0.047547724160827975,
#      -0.2513047408863489,
#      -0.3597390877319482,
#      -0.36755916152463186,
#      -0.47727686321789886,
#      -0.6084451360700607,
#      -0.6857196202124092,
#      -0.7230363492803988,
#      -0.7806361054946436,
#      -0.8025775494091416,
#      -0.8944516182777047,
#      -0.9335606569953789,
#      -0.9460422501202502,
#      -0.9543679169143147,
#      -1.0010607464834962,
#      -1.002398778988459,
#      -1.0328567468458152,
#      -1.0343519471587248,
#      -1.0425780934417261,
#      -1.0483139729084563,
#      -1.1322460252051947,
#      -1.1329790618731064,
#      -1.1692414589511753,
#      -1.2114281877805742,
#      -1.2258479350764961,
#      -1.2290555180487646,
#      -1.2719059993236104,
#      -1.2800218240110137]}},
#   {'training': {'epochs': [{'accuracy': 0.158203125,
#       'crossentropy': 2.2064781188964844},
#      {'accuracy': 0.444580078125, 'crossentropy': 1.687636375427246},
#      {'accuracy': 0.70458984375, 'crossentropy': 1.0749810934066772},
#      {'accuracy': 0.7666015625, 'crossentropy': 0.7851215600967407},
#      {'accuracy': 0.80908203125, 'crossentropy': 0.6331435441970825},
#      {'accuracy': 0.818603515625, 'crossentropy': 0.5901303291320801},
#      {'accuracy': 0.81787109375, 'crossentropy': 0.5718908905982971},
#      {'accuracy': 0.856689453125, 'crossentropy': 0.5258233547210693},
#      {'accuracy': 0.850830078125, 'crossentropy': 0.5008416771888733},
#      {'accuracy': 0.844482421875, 'crossentropy': 0.4872267544269562},
#      {'accuracy': 0.857421875, 'crossentropy': 0.45097169280052185},
#      {'accuracy': 0.857666015625, 'crossentropy': 0.47887668013572693},
#      {'accuracy': 0.83203125, 'crossentropy': 0.49969494342803955},
#      {'accuracy': 0.85546875, 'crossentropy': 0.4792522192001343},
#      {'accuracy': 0.846435546875, 'crossentropy': 0.48290854692459106},
#      {'accuracy': 0.856689453125, 'crossentropy': 0.47611626982688904},
#      {'accuracy': 0.85205078125, 'crossentropy': 0.47238337993621826},
#      {'accuracy': 0.857421875, 'crossentropy': 0.48335030674934387},
#      {'accuracy': 0.86279296875, 'crossentropy': 0.4274550974369049},
#      {'accuracy': 0.86669921875, 'crossentropy': 0.44718262553215027},
#      {'accuracy': 0.868896484375, 'crossentropy': 0.4319808781147003},
#      {'accuracy': 0.86865234375, 'crossentropy': 0.4490266740322113},
#      {'accuracy': 0.867919921875, 'crossentropy': 0.4336508512496948},
#      {'accuracy': 0.848388671875, 'crossentropy': 0.49540379643440247},
#      {'accuracy': 0.861572265625, 'crossentropy': 0.4712793231010437},
#      {'accuracy': 0.859619140625, 'crossentropy': 0.45154398679733276},
#      {'accuracy': 0.86669921875, 'crossentropy': 0.4474200904369354},
#      {'accuracy': 0.869873046875, 'crossentropy': 0.43515849113464355},
#      {'accuracy': 0.870361328125, 'crossentropy': 0.42721548676490784},
#      {'accuracy': 0.8623046875, 'crossentropy': 0.4485985040664673},
#      {'accuracy': 0.853271484375, 'crossentropy': 0.44204241037368774},
#      {'accuracy': 0.854248046875, 'crossentropy': 0.46449756622314453},
#      {'accuracy': 0.863525390625, 'crossentropy': 0.45361992716789246},
#      {'accuracy': 0.86669921875, 'crossentropy': 0.4433276355266571},
#      {'accuracy': 0.870849609375, 'crossentropy': 0.43781277537345886},
#      {'accuracy': 0.8671875, 'crossentropy': 0.43844127655029297},
#      {'accuracy': 0.868896484375, 'crossentropy': 0.45106348395347595},
#      {'accuracy': 0.858642578125, 'crossentropy': 0.45449918508529663},
#      {'accuracy': 0.852783203125, 'crossentropy': 0.4645337462425232},
#      {'accuracy': 0.8515625, 'crossentropy': 0.4873301088809967},
#      {'accuracy': 0.849609375, 'crossentropy': 0.49934056401252747},
#      {'accuracy': 0.86474609375, 'crossentropy': 0.46518850326538086},
#      {'accuracy': 0.856689453125, 'crossentropy': 0.4923343360424042},
#      {'accuracy': 0.85400390625, 'crossentropy': 0.5072774291038513},
#      {'accuracy': 0.84912109375, 'crossentropy': 0.5042523145675659},
#      {'accuracy': 0.85498046875, 'crossentropy': 0.470112681388855},
#      {'accuracy': 0.852294921875, 'crossentropy': 0.4862450361251831},
#      {'accuracy': 0.86279296875, 'crossentropy': 0.4539099931716919},
#      {'accuracy': 0.858154296875, 'crossentropy': 0.5077624917030334},
#      {'accuracy': 0.857666015625, 'crossentropy': 0.4813677668571472},
#      {'accuracy': 0.8623046875, 'crossentropy': 0.5125234127044678},
#      {'accuracy': 0.86083984375, 'crossentropy': 0.47485125064849854},
#      {'accuracy': 0.865478515625, 'crossentropy': 0.4655707776546478},
#      {'accuracy': 0.860595703125, 'crossentropy': 0.4860525131225586},
#      {'accuracy': 0.859130859375, 'crossentropy': 0.4838036000728607}],
#     'best_epoch': 34},
#    'evaluation_metrics': {'accuracy': 0.8718,
#     'crossentropy': 0.4051850438117981},
#    'acquisition': {'indices': [['id', 53876],
#      ['id', 12872],
#      ['id', 28126],
#      ['id', 6982],
#      ['id', 16049],
#      ['id', 30393],
#      ['id', 48740],
#      ['id', 8937],
#      ['id', 23308],
#      ['id', 28127],
#      ['id', 48154],
#      ['id', 28852],
#      ['id', 3333],
#      ['id', 16372],
#      ['id', 20396],
#      ['id', 13623],
#      ['id', 4546],
#      ['id', 8936],
#      ['id', 54211],
#      ['id', 23002],
#      ['id', 49183],
#      ['id', 38631],
#      ['id', 45526],
#      ['id', 3289],
#      ['id', 37733],
#      ['id', 37094],
#      ['id', 8789],
#      ['id', 47072],
#      ['id', 12035],
#      ['id', 21901],
#      ['id', 25855],
#      ['id', 7780],
#      ['id', 53877],
#      ['id', 4830],
#      ['id', 1681],
#      ['id', 20411],
#      ['id', 35352],
#      ['id', 23493],
#      ['id', 3390],
#      ['id', 8869]],
#     'labels': [7,
#      8,
#      4,
#      8,
#      1,
#      7,
#      9,
#      3,
#      2,
#      7,
#      3,
#      2,
#      9,
#      6,
#      3,
#      9,
#      3,
#      3,
#      6,
#      3,
#      0,
#      9,
#      6,
#      5,
#      7,
#      0,
#      2,
#      5,
#      0,
#      4,
#      2,
#      9,
#      4,
#      8,
#      4,
#      7,
#      2,
#      7,
#      3,
#      4],
#     'scores': [2.2756142799699743,
#      0.8025845256464637,
#      0.6708494876504368,
#      0.46788072345782616,
#      0.31382657480846987,
#      0.20298045906452078,
#      0.19732860342863034,
#      0.06794329045891878,
#      -0.005709005219157959,
#      -0.05613269986402614,
#      -0.10402548218814012,
#      -0.16620496170956756,
#      -0.2625188126433149,
#      -0.32847511110689753,
#      -0.37302874803365604,
#      -0.4626131785453076,
#      -0.4774174787818293,
#      -0.503856933211555,
#      -0.5374064124024649,
#      -0.5381423194057513,
#      -0.5923376051292024,
#      -0.7486380593102098,
#      -0.965238473625603,
#      -0.9833503882006855,
#      -1.0000159146870065,
#      -1.0450255100851384,
#      -1.2206959424110133,
#      -1.241445004446799,
#      -1.288370710553325,
#      -1.3009834295169425,
#      -1.3341091248306607,
#      -1.342565875568912,
#      -1.360620070925763,
#      -1.364278011582119,
#      -1.3695920442366352,
#      -1.3803966683233586,
#      -1.4255198762296235,
#      -1.4316302807860573,
#      -1.4393071839390343,
#      -1.4672984818771946]}},
#   {'training': {'epochs': [{'accuracy': 0.176513671875,
#       'crossentropy': 2.2206220626831055},
#      {'accuracy': 0.48828125, 'crossentropy': 1.7197474241256714},
#      {'accuracy': 0.6484375, 'crossentropy': 1.1477694511413574},
#      {'accuracy': 0.7900390625, 'crossentropy': 0.7956662774085999},
#      {'accuracy': 0.80712890625, 'crossentropy': 0.677318274974823},
#      {'accuracy': 0.8427734375, 'crossentropy': 0.5638805627822876},
#      {'accuracy': 0.863037109375, 'crossentropy': 0.5010529160499573},
#      {'accuracy': 0.86083984375, 'crossentropy': 0.46056902408599854},
#      {'accuracy': 0.86962890625, 'crossentropy': 0.43548744916915894},
#      {'accuracy': 0.87060546875, 'crossentropy': 0.4181094467639923},
#      {'accuracy': 0.868896484375, 'crossentropy': 0.4216543436050415},
#      {'accuracy': 0.87744140625, 'crossentropy': 0.4238310158252716},
#      {'accuracy': 0.879150390625, 'crossentropy': 0.3968002498149872},
#      {'accuracy': 0.882568359375, 'crossentropy': 0.37793418765068054},
#      {'accuracy': 0.885009765625, 'crossentropy': 0.3606567680835724},
#      {'accuracy': 0.880859375, 'crossentropy': 0.3713604509830475},
#      {'accuracy': 0.887451171875, 'crossentropy': 0.365386426448822},
#      {'accuracy': 0.884033203125, 'crossentropy': 0.3745824694633484},
#      {'accuracy': 0.88525390625, 'crossentropy': 0.3708645701408386},
#      {'accuracy': 0.87890625, 'crossentropy': 0.3764679431915283},
#      {'accuracy': 0.88330078125, 'crossentropy': 0.3737909495830536},
#      {'accuracy': 0.878173828125, 'crossentropy': 0.38372740149497986},
#      {'accuracy': 0.884033203125, 'crossentropy': 0.3738662302494049},
#      {'accuracy': 0.8837890625, 'crossentropy': 0.3581846356391907},
#      {'accuracy': 0.87744140625, 'crossentropy': 0.40184667706489563},
#      {'accuracy': 0.886962890625, 'crossentropy': 0.363374799489975},
#      {'accuracy': 0.884521484375, 'crossentropy': 0.3672535717487335},
#      {'accuracy': 0.88916015625, 'crossentropy': 0.35827136039733887},
#      {'accuracy': 0.892333984375, 'crossentropy': 0.3483538031578064},
#      {'accuracy': 0.8857421875, 'crossentropy': 0.38185226917266846},
#      {'accuracy': 0.891357421875, 'crossentropy': 0.3551236391067505},
#      {'accuracy': 0.890380859375, 'crossentropy': 0.3537570834159851},
#      {'accuracy': 0.892822265625, 'crossentropy': 0.35715317726135254},
#      {'accuracy': 0.89404296875, 'crossentropy': 0.3517734706401825},
#      {'accuracy': 0.8935546875, 'crossentropy': 0.3392280042171478},
#      {'accuracy': 0.899169921875, 'crossentropy': 0.3386153280735016},
#      {'accuracy': 0.896484375, 'crossentropy': 0.3308787941932678},
#      {'accuracy': 0.902099609375, 'crossentropy': 0.32976585626602173},
#      {'accuracy': 0.896728515625, 'crossentropy': 0.33752012252807617},
#      {'accuracy': 0.898193359375, 'crossentropy': 0.33682119846343994},
#      {'accuracy': 0.89990234375, 'crossentropy': 0.3211551606655121},
#      {'accuracy': 0.896484375, 'crossentropy': 0.34418341517448425},
#      {'accuracy': 0.89404296875, 'crossentropy': 0.32919904589653015},
#      {'accuracy': 0.901123046875, 'crossentropy': 0.315908819437027},
#      {'accuracy': 0.9033203125, 'crossentropy': 0.3115004301071167},
#      {'accuracy': 0.89794921875, 'crossentropy': 0.33827269077301025},
#      {'accuracy': 0.8955078125, 'crossentropy': 0.3343103528022766},
#      {'accuracy': 0.892333984375, 'crossentropy': 0.36130383610725403},
#      {'accuracy': 0.89794921875, 'crossentropy': 0.3546743094921112},
#      {'accuracy': 0.898193359375, 'crossentropy': 0.3322097063064575},
#      {'accuracy': 0.906005859375, 'crossentropy': 0.32254526019096375},
#      {'accuracy': 0.902099609375, 'crossentropy': 0.32557687163352966},
#      {'accuracy': 0.899169921875, 'crossentropy': 0.32571813464164734},
#      {'accuracy': 0.888916015625, 'crossentropy': 0.3910001814365387},
#      {'accuracy': 0.885009765625, 'crossentropy': 0.3553909957408905},
#      {'accuracy': 0.900634765625, 'crossentropy': 0.33626699447631836},
#      {'accuracy': 0.89599609375, 'crossentropy': 0.34901684522628784},
#      {'accuracy': 0.896240234375, 'crossentropy': 0.33295324444770813},
#      {'accuracy': 0.895263671875, 'crossentropy': 0.36238008737564087},
#      {'accuracy': 0.89306640625, 'crossentropy': 0.34708285331726074},
#      {'accuracy': 0.89990234375, 'crossentropy': 0.330861359834671},
#      {'accuracy': 0.894775390625, 'crossentropy': 0.34135469794273376},
#      {'accuracy': 0.89501953125, 'crossentropy': 0.34099724888801575},
#      {'accuracy': 0.8974609375, 'crossentropy': 0.3385234773159027},
#      {'accuracy': 0.883056640625, 'crossentropy': 0.3781109154224396},
#      {'accuracy': 0.901123046875, 'crossentropy': 0.3251405656337738},
#      {'accuracy': 0.90234375, 'crossentropy': 0.3295031189918518},
#      {'accuracy': 0.896728515625, 'crossentropy': 0.33834484219551086},
#      {'accuracy': 0.899169921875, 'crossentropy': 0.3327324092388153},
#      {'accuracy': 0.896240234375, 'crossentropy': 0.34422510862350464},
#      {'accuracy': 0.8935546875, 'crossentropy': 0.35930919647216797}],
#     'best_epoch': 50},
#    'evaluation_metrics': {'accuracy': 0.9076,
#     'crossentropy': 0.325528085231781},
#    'acquisition': {'indices': [['id', 35175],
#      ['id', 52350],
#      ['id', 23976],
#      ['id', 34702],
#      ['id', 24035],
#      ['id', 34290],
#      ['id', 29932],
#      ['id', 38552],
#      ['id', 34703],
#      ['id', 2868],
#      ['id', 12188],
#      ['id', 31531],
#      ['id', 36504],
#      ['id', 52419],
#      ['id', 22122],
#      ['id', 5318],
#      ['id', 23166],
#      ['id', 49963],
#      ['id', 37358],
#      ['id', 44965],
#      ['id', 44502],
#      ['id', 36806],
#      ['id', 9407],
#      ['id', 9560],
#      ['id', 21671],
#      ['id', 55820],
#      ['id', 30055],
#      ['id', 23488],
#      ['id', 25819],
#      ['id', 14412],
#      ['id', 28055],
#      ['id', 1333],
#      ['id', 2522],
#      ['id', 44281],
#      ['id', 53354],
#      ['id', 29507],
#      ['id', 34850],
#      ['id', 18942],
#      ['id', 43102],
#      ['id', 31530]],
#     'labels': [2,
#      5,
#      1,
#      6,
#      4,
#      6,
#      9,
#      4,
#      3,
#      7,
#      9,
#      9,
#      2,
#      1,
#      0,
#      6,
#      1,
#      0,
#      5,
#      4,
#      4,
#      9,
#      2,
#      3,
#      8,
#      0,
#      7,
#      8,
#      5,
#      9,
#      0,
#      0,
#      3,
#      6,
#      1,
#      9,
#      7,
#      0,
#      1,
#      6],
#     'scores': [4.600905072201829,
#      4.310094071502052,
#      3.360427682893924,
#      1.2479080078472085,
#      1.2213304276552233,
#      0.9815694514777107,
#      0.3733973337344665,
#      0.22407204022683924,
#      0.1623429899042832,
#      0.028070323599569846,
#      -0.05233136859493559,
#      -0.05978757725285222,
#      -0.06160683720614735,
#      -0.08867032040965084,
#      -0.09710529446563321,
#      -0.12939436346096933,
#      -0.22237328919732136,
#      -0.279341277645643,
#      -0.30609141981182564,
#      -0.32184373736396754,
#      -0.3605391817330421,
#      -0.42741620946442715,
#      -0.43228958123481753,
#      -0.4890313398567544,
#      -0.5071941403043567,
#      -0.7825225827918612,
#      -0.7964879706122323,
#      -0.8120680390874209,
#      -0.820715335810899,
#      -0.8651224603917353,
#      -0.8866268665001922,
#      -0.9098045396568364,
#      -1.0652209297026474,
#      -1.1974048772102641,
#      -1.203250424037095,
#      -1.204019541796698,
#      -1.2377369716379025,
#      -1.2423930907959644,
#      -1.2714861397161719,
#      -1.2776866298471532]}},
#   {'training': {'epochs': [{'accuracy': 0.207763671875,
#       'crossentropy': 2.1911709308624268},
#      {'accuracy': 0.35107421875, 'crossentropy': 1.7268226146697998},
#      {'accuracy': 0.627197265625, 'crossentropy': 1.2922271490097046},
#      {'accuracy': 0.78955078125, 'crossentropy': 0.8878527879714966},
#      {'accuracy': 0.865966796875, 'crossentropy': 0.6879711151123047},
#      {'accuracy': 0.892333984375, 'crossentropy': 0.5089395642280579},
#      {'accuracy': 0.891357421875, 'crossentropy': 0.4685576260089874},
#      {'accuracy': 0.920166015625, 'crossentropy': 0.4078972339630127},
#      {'accuracy': 0.90625, 'crossentropy': 0.3970099091529846},
#      {'accuracy': 0.9208984375, 'crossentropy': 0.34533247351646423},
#      {'accuracy': 0.920654296875, 'crossentropy': 0.33741387724876404},
#      {'accuracy': 0.92724609375, 'crossentropy': 0.29869940876960754},
#      {'accuracy': 0.92626953125, 'crossentropy': 0.2877672612667084},
#      {'accuracy': 0.927490234375, 'crossentropy': 0.28992047905921936},
#      {'accuracy': 0.922119140625, 'crossentropy': 0.2848031222820282},
#      {'accuracy': 0.931640625, 'crossentropy': 0.25638750195503235},
#      {'accuracy': 0.932861328125, 'crossentropy': 0.2715334892272949},
#      {'accuracy': 0.93115234375, 'crossentropy': 0.25269076228141785},
#      {'accuracy': 0.92431640625, 'crossentropy': 0.2647779583930969},
#      {'accuracy': 0.928955078125, 'crossentropy': 0.2577649652957916},
#      {'accuracy': 0.930419921875, 'crossentropy': 0.2626954913139343},
#      {'accuracy': 0.928955078125, 'crossentropy': 0.265230268239975},
#      {'accuracy': 0.927734375, 'crossentropy': 0.2637925148010254},
#      {'accuracy': 0.9326171875, 'crossentropy': 0.2457696944475174},
#      {'accuracy': 0.93359375, 'crossentropy': 0.23818504810333252},
#      {'accuracy': 0.93505859375, 'crossentropy': 0.24198752641677856},
#      {'accuracy': 0.93896484375, 'crossentropy': 0.23275679349899292},
#      {'accuracy': 0.93310546875, 'crossentropy': 0.2403312772512436},
#      {'accuracy': 0.92919921875, 'crossentropy': 0.2539774179458618},
#      {'accuracy': 0.93359375, 'crossentropy': 0.2379763275384903},
#      {'accuracy': 0.93408203125, 'crossentropy': 0.22726236283779144},
#      {'accuracy': 0.934814453125, 'crossentropy': 0.23157700896263123},
#      {'accuracy': 0.931640625, 'crossentropy': 0.24211135506629944},
#      {'accuracy': 0.9345703125, 'crossentropy': 0.23364314436912537},
#      {'accuracy': 0.931884765625, 'crossentropy': 0.24592100083827972},
#      {'accuracy': 0.92431640625, 'crossentropy': 0.25732722878456116},
#      {'accuracy': 0.93408203125, 'crossentropy': 0.23154395818710327},
#      {'accuracy': 0.9296875, 'crossentropy': 0.23913849890232086},
#      {'accuracy': 0.937255859375, 'crossentropy': 0.24276068806648254},
#      {'accuracy': 0.93408203125, 'crossentropy': 0.2329685389995575},
#      {'accuracy': 0.935546875, 'crossentropy': 0.22979862987995148},
#      {'accuracy': 0.936279296875, 'crossentropy': 0.23142412304878235},
#      {'accuracy': 0.93701171875, 'crossentropy': 0.22722098231315613},
#      {'accuracy': 0.938720703125, 'crossentropy': 0.22782903909683228},
#      {'accuracy': 0.9345703125, 'crossentropy': 0.24461695551872253},
#      {'accuracy': 0.9365234375, 'crossentropy': 0.2270466387271881},
#      {'accuracy': 0.936279296875, 'crossentropy': 0.22280073165893555}],
#     'best_epoch': 26},
#    'evaluation_metrics': {'accuracy': 0.9329,
#     'crossentropy': 0.2435976266860962},
#    'acquisition': {'indices': [['id', 38873],
#      ['id', 52559],
#      ['id', 38987],
#      ['id', 4885],
#      ['id', 13334],
#      ['id', 53658],
#      ['id', 23139],
#      ['id', 52558],
#      ['id', 8251],
#      ['id', 24658],
#      ['id', 19097],
#      ['id', 37278],
#      ['id', 12124],
#      ['id', 9559],
#      ['id', 1233],
#      ['id', 7886],
#      ['id', 38997],
#      ['id', 20570],
#      ['id', 28767],
#      ['id', 49967],
#      ['id', 40829],
#      ['id', 51777],
#      ['id', 55259],
#      ['id', 7127],
#      ['id', 6705],
#      ['id', 35661],
#      ['id', 45276],
#      ['id', 40287],
#      ['id', 7248],
#      ['id', 13004],
#      ['id', 50153],
#      ['id', 51350],
#      ['id', 54765],
#      ['id', 19680],
#      ['id', 45025],
#      ['id', 1600],
#      ['id', 9697],
#      ['id', 16078],
#      ['id', 8373],
#      ['id', 4537]],
#     'labels': [4,
#      1,
#      2,
#      1,
#      6,
#      0,
#      7,
#      5,
#      7,
#      6,
#      3,
#      2,
#      7,
#      3,
#      7,
#      5,
#      0,
#      3,
#      1,
#      0,
#      4,
#      8,
#      5,
#      5,
#      8,
#      1,
#      3,
#      6,
#      4,
#      3,
#      9,
#      1,
#      8,
#      9,
#      1,
#      8,
#      1,
#      8,
#      8,
#      6],
#     'scores': [2.830062271495425,
#      1.1382924438789368,
#      0.764597608898967,
#      0.5173197764453179,
#      0.45480990578518643,
#      0.15726090615252275,
#      0.15050949997693408,
#      -0.12504623549751748,
#      -0.19709927571368535,
#      -0.2850653060983914,
#      -0.33293840123100615,
#      -0.36380133509192447,
#      -0.38799885030884806,
#      -0.42925120597595434,
#      -0.504059324382883,
#      -0.5202743228132292,
#      -0.6292640059973422,
#      -0.7225213903385104,
#      -0.7475244531436376,
#      -0.799825307440404,
#      -0.8365524131241759,
#      -0.8601800110775089,
#      -0.8826909063893416,
#      -0.9214248900103161,
#      -1.0011804392568937,
#      -1.0038236764408084,
#      -1.0235403720525484,
#      -1.0468875818741168,
#      -1.1538223279740611,
#      -1.2230373641770456,
#      -1.2453784831016925,
#      -1.2527509136736361,
#      -1.3717097349839191,
#      -1.395249164602463,
#      -1.4372997400932754,
#      -1.440924749354766,
#      -1.4463383757416044,
#      -1.4482236028475235,
#      -1.4541184336429644,
#      -1.5110796911960724]}},
#   {'training': {'epochs': [{'accuracy': 0.19677734375,
#       'crossentropy': 2.234217882156372},
#      {'accuracy': 0.287353515625, 'crossentropy': 1.932382345199585},
#      {'accuracy': 0.54296875, 'crossentropy': 1.4334663152694702},
#      {'accuracy': 0.792724609375, 'crossentropy': 0.9874423146247864},
#      {'accuracy': 0.83056640625, 'crossentropy': 0.7416061758995056},
#      {'accuracy': 0.884521484375, 'crossentropy': 0.5937093496322632},
#      {'accuracy': 0.90380859375, 'crossentropy': 0.5010399222373962},
#      {'accuracy': 0.894287109375, 'crossentropy': 0.4222303628921509},
#      {'accuracy': 0.92236328125, 'crossentropy': 0.3862587809562683},
#      {'accuracy': 0.931640625, 'crossentropy': 0.3455964922904968},
#      {'accuracy': 0.929443359375, 'crossentropy': 0.33061543107032776},
#      {'accuracy': 0.937744140625, 'crossentropy': 0.2925741672515869},
#      {'accuracy': 0.929443359375, 'crossentropy': 0.27741214632987976},
#      {'accuracy': 0.94189453125, 'crossentropy': 0.263846218585968},
#      {'accuracy': 0.92822265625, 'crossentropy': 0.2722407281398773},
#      {'accuracy': 0.94580078125, 'crossentropy': 0.2488650679588318},
#      {'accuracy': 0.928955078125, 'crossentropy': 0.2712288200855255},
#      {'accuracy': 0.943603515625, 'crossentropy': 0.2412065714597702},
#      {'accuracy': 0.944580078125, 'crossentropy': 0.23554784059524536},
#      {'accuracy': 0.942138671875, 'crossentropy': 0.22173263132572174},
#      {'accuracy': 0.9423828125, 'crossentropy': 0.2328154444694519},
#      {'accuracy': 0.947509765625, 'crossentropy': 0.21844683587551117},
#      {'accuracy': 0.9501953125, 'crossentropy': 0.2057231068611145},
#      {'accuracy': 0.943359375, 'crossentropy': 0.21461306512355804},
#      {'accuracy': 0.946533203125, 'crossentropy': 0.22200703620910645},
#      {'accuracy': 0.950927734375, 'crossentropy': 0.2061808556318283},
#      {'accuracy': 0.94677734375, 'crossentropy': 0.21221263706684113},
#      {'accuracy': 0.937255859375, 'crossentropy': 0.21891069412231445},
#      {'accuracy': 0.9443359375, 'crossentropy': 0.21752333641052246},
#      {'accuracy': 0.942626953125, 'crossentropy': 0.21832974255084991},
#      {'accuracy': 0.943603515625, 'crossentropy': 0.217246413230896},
#      {'accuracy': 0.945068359375, 'crossentropy': 0.2127683162689209},
#      {'accuracy': 0.947509765625, 'crossentropy': 0.2034059762954712},
#      {'accuracy': 0.94482421875, 'crossentropy': 0.20449130237102509},
#      {'accuracy': 0.940673828125, 'crossentropy': 0.20916177332401276},
#      {'accuracy': 0.94140625, 'crossentropy': 0.2068033516407013},
#      {'accuracy': 0.945068359375, 'crossentropy': 0.19982153177261353},
#      {'accuracy': 0.945068359375, 'crossentropy': 0.19958704710006714},
#      {'accuracy': 0.94580078125, 'crossentropy': 0.19775010645389557},
#      {'accuracy': 0.947998046875, 'crossentropy': 0.19082875549793243},
#      {'accuracy': 0.948974609375, 'crossentropy': 0.1877426952123642},
#      {'accuracy': 0.952392578125, 'crossentropy': 0.18783357739448547},
#      {'accuracy': 0.948486328125, 'crossentropy': 0.19265371561050415},
#      {'accuracy': 0.945068359375, 'crossentropy': 0.1891375482082367},
#      {'accuracy': 0.949462890625, 'crossentropy': 0.19102488458156586},
#      {'accuracy': 0.94580078125, 'crossentropy': 0.19686751067638397},
#      {'accuracy': 0.947998046875, 'crossentropy': 0.1882888525724411},
#      {'accuracy': 0.943359375, 'crossentropy': 0.19599537551403046},
#      {'accuracy': 0.94873046875, 'crossentropy': 0.18436869978904724},
#      {'accuracy': 0.9453125, 'crossentropy': 0.18681102991104126},
#      {'accuracy': 0.94970703125, 'crossentropy': 0.181631937623024},
#      {'accuracy': 0.950927734375, 'crossentropy': 0.1866401731967926},
#      {'accuracy': 0.950439453125, 'crossentropy': 0.18875384330749512},
#      {'accuracy': 0.948486328125, 'crossentropy': 0.1869485080242157},
#      {'accuracy': 0.946044921875, 'crossentropy': 0.196498304605484},
#      {'accuracy': 0.94775390625, 'crossentropy': 0.18444302678108215},
#      {'accuracy': 0.945068359375, 'crossentropy': 0.18854239583015442},
#      {'accuracy': 0.947021484375, 'crossentropy': 0.19165641069412231},
#      {'accuracy': 0.945556640625, 'crossentropy': 0.19229550659656525},
#      {'accuracy': 0.946533203125, 'crossentropy': 0.18530268967151642},
#      {'accuracy': 0.94287109375, 'crossentropy': 0.19981348514556885},
#      {'accuracy': 0.939453125, 'crossentropy': 0.2020450085401535}],
#     'best_epoch': 41},
#    'evaluation_metrics': {'accuracy': 0.9502,
#     'crossentropy': 0.17845892906188965},
#    'acquisition': {'indices': [['id', 32583],
#      ['id', 11382],
#      ['id', 11383],
#      ['id', 54473],
#      ['id', 6039],
#      ['id', 18931],
#      ['id', 35596],
#      ['id', 10997],
#      ['id', 26179],
#      ['id', 40171],
#      ['id', 38053],
#      ['id', 42839],
#      ['id', 46931],
#      ['id', 31378],
#      ['id', 23392],
#      ['id', 1661],
#      ['id', 51559],
#      ['id', 10509],
#      ['id', 47455],
#      ['id', 6801],
#      ['id', 36096],
#      ['id', 45651],
#      ['id', 3203],
#      ['id', 27917],
#      ['id', 48096],
#      ['id', 27898],
#      ['id', 3167],
#      ['id', 55424],
#      ['id', 4033],
#      ['id', 33290],
#      ['id', 16901],
#      ['id', 28101],
#      ['id', 12695],
#      ['id', 46976],
#      ['id', 46376],
#      ['id', 29343],
#      ['id', 9704],
#      ['id', 5091],
#      ['id', 29761],
#      ['id', 44538]],
#     'labels': [3,
#      8,
#      4,
#      1,
#      8,
#      5,
#      9,
#      2,
#      5,
#      6,
#      8,
#      5,
#      4,
#      0,
#      2,
#      1,
#      6,
#      0,
#      7,
#      2,
#      7,
#      9,
#      5,
#      3,
#      7,
#      9,
#      1,
#      9,
#      1,
#      5,
#      6,
#      8,
#      8,
#      4,
#      2,
#      4,
#      2,
#      9,
#      7,
#      3],
#     'scores': [2.570065718209448,
#      1.8739181530426539,
#      1.7979803217974055,
#      1.3710558015224308,
#      1.3346459642773993,
#      0.9362991133302998,
#      0.8500361923267956,
#      0.33782155352339505,
#      -0.06119359588556206,
#      -0.0793548417221257,
#      -0.1998709347557588,
#      -0.27929122692394515,
#      -0.2822147215590318,
#      -0.3121961981192838,
#      -0.3886996417710815,
#      -0.45725762147210247,
#      -0.47418508155705696,
#      -0.6900046265289599,
#      -0.7984897214447972,
#      -0.8342331214783529,
#      -0.8827678840045727,
#      -0.9176160123767074,
#      -0.9184723578670475,
#      -0.9629642018029205,
#      -0.9834401666306682,
#      -1.0539885462776333,
#      -1.18189588273638,
#      -1.1892426686715432,
#      -1.2743722413472192,
#      -1.3099994730788893,
#      -1.3351885500116891,
#      -1.3824282107241803,
#      -1.4040712360813128,
#      -1.4091425182000448,
#      -1.4101961343310068,
#      -1.4632890354188,
#      -1.4723977861752289,
#      -1.4996963138907908,
#      -1.5449718526068237,
#      -1.5826915087143902]}},
#   {'training': {'epochs': [{'accuracy': 0.161865234375,
#       'crossentropy': 2.224942922592163},
#      {'accuracy': 0.3505859375, 'crossentropy': 1.8767552375793457},
#      {'accuracy': 0.670654296875, 'crossentropy': 1.3607568740844727},
#      {'accuracy': 0.808349609375, 'crossentropy': 0.9978023171424866},
#      {'accuracy': 0.872314453125, 'crossentropy': 0.6950159072875977},
#      {'accuracy': 0.908447265625, 'crossentropy': 0.5501756072044373},
#      {'accuracy': 0.923583984375, 'crossentropy': 0.45276159048080444},
#      {'accuracy': 0.935546875, 'crossentropy': 0.3710895776748657},
#      {'accuracy': 0.94140625, 'crossentropy': 0.35739585757255554},
#      {'accuracy': 0.927490234375, 'crossentropy': 0.3365728259086609},
#      {'accuracy': 0.939208984375, 'crossentropy': 0.31508514285087585},
#      {'accuracy': 0.946044921875, 'crossentropy': 0.27317288517951965},
#      {'accuracy': 0.94189453125, 'crossentropy': 0.26885101199150085},
#      {'accuracy': 0.946044921875, 'crossentropy': 0.25491613149642944},
#      {'accuracy': 0.95166015625, 'crossentropy': 0.22690586745738983},
#      {'accuracy': 0.9482421875, 'crossentropy': 0.22266820073127747},
#      {'accuracy': 0.946044921875, 'crossentropy': 0.2279767245054245},
#      {'accuracy': 0.9482421875, 'crossentropy': 0.2235807478427887},
#      {'accuracy': 0.950439453125, 'crossentropy': 0.21258755028247833},
#      {'accuracy': 0.94970703125, 'crossentropy': 0.20549356937408447},
#      {'accuracy': 0.947021484375, 'crossentropy': 0.2036665827035904},
#      {'accuracy': 0.94921875, 'crossentropy': 0.20520535111427307},
#      {'accuracy': 0.94873046875, 'crossentropy': 0.20566631853580475},
#      {'accuracy': 0.952880859375, 'crossentropy': 0.18867707252502441},
#      {'accuracy': 0.95263671875, 'crossentropy': 0.1869545876979828},
#      {'accuracy': 0.95263671875, 'crossentropy': 0.19191426038742065},
#      {'accuracy': 0.947509765625, 'crossentropy': 0.1938769668340683},
#      {'accuracy': 0.951171875, 'crossentropy': 0.1837826520204544},
#      {'accuracy': 0.94873046875, 'crossentropy': 0.1832418292760849},
#      {'accuracy': 0.950927734375, 'crossentropy': 0.18383605778217316},
#      {'accuracy': 0.95166015625, 'crossentropy': 0.18146732449531555},
#      {'accuracy': 0.953125, 'crossentropy': 0.17558646202087402},
#      {'accuracy': 0.951904296875, 'crossentropy': 0.17667452991008759},
#      {'accuracy': 0.953857421875, 'crossentropy': 0.17142167687416077},
#      {'accuracy': 0.949951171875, 'crossentropy': 0.1805737018585205},
#      {'accuracy': 0.952392578125, 'crossentropy': 0.17865464091300964},
#      {'accuracy': 0.952880859375, 'crossentropy': 0.1763426810503006},
#      {'accuracy': 0.954345703125, 'crossentropy': 0.1809321641921997},
#      {'accuracy': 0.95166015625, 'crossentropy': 0.18088029325008392},
#      {'accuracy': 0.95263671875, 'crossentropy': 0.1774521768093109},
#      {'accuracy': 0.95166015625, 'crossentropy': 0.18101923167705536},
#      {'accuracy': 0.94287109375, 'crossentropy': 0.19440534710884094},
#      {'accuracy': 0.949951171875, 'crossentropy': 0.178827702999115},
#      {'accuracy': 0.949951171875, 'crossentropy': 0.18217971920967102},
#      {'accuracy': 0.9482421875, 'crossentropy': 0.17701248824596405},
#      {'accuracy': 0.946533203125, 'crossentropy': 0.18207381665706635},
#      {'accuracy': 0.949462890625, 'crossentropy': 0.1720256507396698},
#      {'accuracy': 0.953857421875, 'crossentropy': 0.17328017950057983},
#      {'accuracy': 0.952392578125, 'crossentropy': 0.17305706441402435},
#      {'accuracy': 0.95361328125, 'crossentropy': 0.16774606704711914},
#      {'accuracy': 0.954833984375, 'crossentropy': 0.17189915478229523},
#      {'accuracy': 0.950439453125, 'crossentropy': 0.18526829779148102},
#      {'accuracy': 0.951171875, 'crossentropy': 0.17841440439224243},
#      {'accuracy': 0.9521484375, 'crossentropy': 0.1749255210161209},
#      {'accuracy': 0.953369140625, 'crossentropy': 0.1749361902475357},
#      {'accuracy': 0.950439453125, 'crossentropy': 0.16916261613368988},
#      {'accuracy': 0.9521484375, 'crossentropy': 0.16707202792167664},
#      {'accuracy': 0.950927734375, 'crossentropy': 0.17043855786323547},
#      {'accuracy': 0.953369140625, 'crossentropy': 0.17741745710372925},
#      {'accuracy': 0.95263671875, 'crossentropy': 0.16728851199150085},
#      {'accuracy': 0.952880859375, 'crossentropy': 0.16955755650997162},
#      {'accuracy': 0.949951171875, 'crossentropy': 0.178083136677742},
#      {'accuracy': 0.9521484375, 'crossentropy': 0.1738242655992508},
#      {'accuracy': 0.955810546875, 'crossentropy': 0.16512511670589447},
#      {'accuracy': 0.953857421875, 'crossentropy': 0.17302636802196503},
#      {'accuracy': 0.953857421875, 'crossentropy': 0.17083749175071716},
#      {'accuracy': 0.955078125, 'crossentropy': 0.16796137392520905},
#      {'accuracy': 0.9501953125, 'crossentropy': 0.17261359095573425},
#      {'accuracy': 0.950439453125, 'crossentropy': 0.18129666149616241},
#      {'accuracy': 0.951416015625, 'crossentropy': 0.1735668033361435},
#      {'accuracy': 0.953125, 'crossentropy': 0.1636219620704651},
#      {'accuracy': 0.951904296875, 'crossentropy': 0.16138240694999695},
#      {'accuracy': 0.951416015625, 'crossentropy': 0.16361568868160248},
#      {'accuracy': 0.950927734375, 'crossentropy': 0.17570286989212036},
#      {'accuracy': 0.953125, 'crossentropy': 0.16578496992588043},
#      {'accuracy': 0.948974609375, 'crossentropy': 0.17982856929302216},
#      {'accuracy': 0.95458984375, 'crossentropy': 0.1602485328912735},
#      {'accuracy': 0.949951171875, 'crossentropy': 0.17205309867858887},
#      {'accuracy': 0.947998046875, 'crossentropy': 0.17349760234355927},
#      {'accuracy': 0.9521484375, 'crossentropy': 0.15984894335269928},
#      {'accuracy': 0.954833984375, 'crossentropy': 0.1660993993282318},
#      {'accuracy': 0.952392578125, 'crossentropy': 0.16570070385932922},
#      {'accuracy': 0.952392578125, 'crossentropy': 0.16773438453674316},
#      {'accuracy': 0.951416015625, 'crossentropy': 0.1737992912530899}],
#     'best_epoch': 63},
#    'evaluation_metrics': {'accuracy': 0.9511,
#     'crossentropy': 0.17147402465343475}}],
#  'actual_name': 'experiment_repeated_mnist_job_305_2022-04-25-143429.py',
#  'actual_path': '/home/blackhc/PycharmProjects/bald-ical/results/stochacq_fig1_repeated_mnist/experiment_repeated_mnist_job_305_2022-04-25-143429.py',
#  'tag': None}

# %%
df_raw = pd.DataFrame.from_dict(results, orient="index")

# %%
df_raw.columns
# Out:
# Index(['timestamp', 'cmdline', 'commit', 'github_url', 'experiment', 'job_id',
#        'worker_id', 'num_workers', 'config', 'log', 'dataset_info',
#        'initial_training_set_indices', 'evaluation_set_indices', 'seed',
#        'active_learning_steps', 'actual_name', 'actual_path', 'tag',
#        'exception'],
#       dtype='object')

# %%
def flatten_dict(d: dict):
    result = {}
    for key, value in d.items():
        if isinstance(value, dict):
            result.update({f"{key}_{subkey}": value for subkey, value in flatten_dict(value).items()})
        else:
            result[key] = value
    return result

# %%
df_raw.iloc[0].config
# Out:
# {'seed': 2070,
#  'experiment_data_config': {'id_dataset_name': 'MNIST',
#   'id_repetitions': 2,
#   'initial_training_set_size': 20,
#   'validation_set_size': 4096,
#   'validation_split_random_state': 0,
#   'evaluation_set_size': 0,
#   'add_dataset_noise': True,
#   'ood_dataset_config': None},
#  'acquisition_size': 40,
#  'max_training_set': 300,
#  'max_training_epochs': 300,
#  'num_pool_samples': 100,
#  'num_validation_samples': 20,
#  'num_training_samples': 1,
#  'device': 'cuda',
#  'acquisition_function': 'batchbald_redux.acquisition_functions.StochasticBALD',
#  'train_eval_model': 'batchbald_redux.train_eval_model.TrainSelfDistillationEvalModel',
#  'model_trainer_factory': 'batchbald_redux.models.MnistModelTrainer',
#  'ensemble_size': 1,
#  'temperature': 1.0,
#  'coldness': 1.0,
#  'stochastic_mode': 'StochasticMode.Softrank',
#  'epig_bootstrap_type': 'BootstrapType.NO_BOOTSTRAP',
#  'epig_bootstrap_factor': 1.0,
#  'epig_dtype': torch.float64,
#  'disable_training_augmentations': False,
#  'cache_explicit_eval_model': False,
#  'resnet18_dropout_head': True}

# %%
import math

# %%
def convert_to_rows(df, exp_type):
    rows = []
    for idx, item in df.iterrows():
        exp_idx = f"{exp_type}_{idx}"
        config_part = {f"cfg_{key}": value for key, value in flatten_dict(item.config).items()}

        current_training_set_size = config_part["cfg_experiment_data_config_initial_training_set_size"]
        acquisition_batch_size = config_part["cfg_acquisition_size"]
        if not isinstance(item.exception, float):
            print(idx, "caught exception: ", item.exception)
            continue
        for step in item.active_learning_steps:
            best_epoch = step["training"]["best_epoch"]
            training_part = {f"training_{key}": value for key, value in step["training"]["epochs"][best_epoch].items()}
            evaluation_part = {f"eval_{key}": value for key, value in step["evaluation_metrics"].items()}
            idx = f"{exp_idx}_{current_training_set_size}"
            row = dict(
                idx=idx,
                exp_idx=exp_idx,
                cfg_exp_type=exp_type,
                **config_part,
                current_training_set_size=current_training_set_size,
                **training_part,
                **evaluation_part,
            )

            # print(current_training_set_size)

            current_training_set_size += acquisition_batch_size
            # assert step["dataset"]["next_training_size"] == current_training_set_size
            # next_training_set_size = step["dataset"]["next_training_size"]

            rows.append(row)

    return pd.DataFrame(rows)


df = convert_to_rows(df_raw, "rmnist")
# Out:
# experiment_repeated_mnist_job_48_2022-05-12-141809.py caught exception:  Traceback (most recent call last):
#   File "/auto/users/andsch/github/active_learning_redux/batchbald_redux/experiment_repeated_mnist.py", line 302, in <module>
#     config.run(store=store)
#   File "/auto/users/andsch/github/active_learning_redux/batchbald_redux/unified_experiment.py", line 274, in run
#     data = self.load_experiment_data()
#   File "/auto/users/andsch/github/active_learning_redux/batchbald_redux/unified_experiment.py", line 253, in load_experiment_data
#     return self.experiment_data_config.load(self.device)
#   File "/auto/users/andsch/github/active_learning_redux/batchbald_redux/experiment_data.py", line 87, in load
#     return load_standard_experiment_data(
#   File "/auto/users/andsch/github/active_learning_redux/batchbald_redux/experiment_data.py", line 112, in load_standard_experiment_data
#     split_dataset = get_dataset(
#   File "/auto/users/andsch/github/active_learning_redux/batchbald_redux/datasets.py", line 563, in get_dataset
#     split_dataset = dataset_factories[name](
#   File "/auto/users/andsch/github/active_learning_redux/batchbald_redux/datasets.py", line 291, in get_MNIST
#     full_train_dataset = FastMNIST(root, train=True, download=True, device=device_hint)
#   File "/auto/users/andsch/github/active_learning_redux/batchbald_redux/fast_mnist.py", line 32, in __init__
#     self.data, self.targets = self.data.to(device), self.targets.to(device)
#   File "/scratch-ssd/andsch/tmp/conda_envs/job-62423/lib/python3.8/site-packages/torch/cuda/__init__.py", line 214, in _lazy_init
#     torch._C._cuda_init()
# RuntimeError: CUDA driver initialization failed, you might not have a CUDA gpu.
#
# experiment_repeated_mnist_job_43_2022-05-12-140717.py caught exception:  Traceback (most recent call last):
#   File "/auto/users/andsch/github/active_learning_redux/batchbald_redux/experiment_repeated_mnist.py", line 302, in <module>
#     config.run(store=store)
#   File "/auto/users/andsch/github/active_learning_redux/batchbald_redux/unified_experiment.py", line 274, in run
#     data = self.load_experiment_data()
#   File "/auto/users/andsch/github/active_learning_redux/batchbald_redux/unified_experiment.py", line 253, in load_experiment_data
#     return self.experiment_data_config.load(self.device)
#   File "/auto/users/andsch/github/active_learning_redux/batchbald_redux/experiment_data.py", line 87, in load
#     return load_standard_experiment_data(
#   File "/auto/users/andsch/github/active_learning_redux/batchbald_redux/experiment_data.py", line 112, in load_standard_experiment_data
#     split_dataset = get_dataset(
#   File "/auto/users/andsch/github/active_learning_redux/batchbald_redux/datasets.py", line 563, in get_dataset
#     split_dataset = dataset_factories[name](
#   File "/auto/users/andsch/github/active_learning_redux/batchbald_redux/datasets.py", line 291, in get_MNIST
#     full_train_dataset = FastMNIST(root, train=True, download=True, device=device_hint)
#   File "/auto/users/andsch/github/active_learning_redux/batchbald_redux/fast_mnist.py", line 32, in __init__
#     self.data, self.targets = self.data.to(device), self.targets.to(device)
#   File "/scratch-ssd/andsch/tmp/conda_envs/job-62416/lib/python3.8/site-packages/torch/cuda/__init__.py", line 214, in _lazy_init
#     torch._C._cuda_init()
# RuntimeError: CUDA driver initialization failed, you might not have a CUDA gpu.
#
# experiment_repeated_mnist_job_44_2022-05-12-140806.py caught exception:  Traceback (most recent call last):
#   File "/auto/users/andsch/github/active_learning_redux/batchbald_redux/experiment_repeated_mnist.py", line 302, in <module>
#     config.run(store=store)
#   File "/auto/users/andsch/github/active_learning_redux/batchbald_redux/unified_experiment.py", line 274, in run
#     data = self.load_experiment_data()
#   File "/auto/users/andsch/github/active_learning_redux/batchbald_redux/unified_experiment.py", line 253, in load_experiment_data
#     return self.experiment_data_config.load(self.device)
#   File "/auto/users/andsch/github/active_learning_redux/batchbald_redux/experiment_data.py", line 87, in load
#     return load_standard_experiment_data(
#   File "/auto/users/andsch/github/active_learning_redux/batchbald_redux/experiment_data.py", line 112, in load_standard_experiment_data
#     split_dataset = get_dataset(
#   File "/auto/users/andsch/github/active_learning_redux/batchbald_redux/datasets.py", line 563, in get_dataset
#     split_dataset = dataset_factories[name](
#   File "/auto/users/andsch/github/active_learning_redux/batchbald_redux/datasets.py", line 291, in get_MNIST
#     full_train_dataset = FastMNIST(root, train=True, download=True, device=device_hint)
#   File "/auto/users/andsch/github/active_learning_redux/batchbald_redux/fast_mnist.py", line 32, in __init__
#     self.data, self.targets = self.data.to(device), self.targets.to(device)
#   File "/scratch-ssd/andsch/tmp/conda_envs/job-62418/lib/python3.8/site-packages/torch/cuda/__init__.py", line 214, in _lazy_init
#     torch._C._cuda_init()
# RuntimeError: CUDA driver initialization failed, you might not have a CUDA gpu.
#
# experiment_repeated_mnist_job_42_2022-05-12-140608.py caught exception:  Traceback (most recent call last):
#   File "/auto/users/andsch/github/active_learning_redux/batchbald_redux/experiment_repeated_mnist.py", line 302, in <module>
#     config.run(store=store)
#   File "/auto/users/andsch/github/active_learning_redux/batchbald_redux/unified_experiment.py", line 274, in run
#     data = self.load_experiment_data()
#   File "/auto/users/andsch/github/active_learning_redux/batchbald_redux/unified_experiment.py", line 253, in load_experiment_data
#     return self.experiment_data_config.load(self.device)
#   File "/auto/users/andsch/github/active_learning_redux/batchbald_redux/experiment_data.py", line 87, in load
#     return load_standard_experiment_data(
#   File "/auto/users/andsch/github/active_learning_redux/batchbald_redux/experiment_data.py", line 112, in load_standard_experiment_data
#     split_dataset = get_dataset(
#   File "/auto/users/andsch/github/active_learning_redux/batchbald_redux/datasets.py", line 563, in get_dataset
#     split_dataset = dataset_factories[name](
#   File "/auto/users/andsch/github/active_learning_redux/batchbald_redux/datasets.py", line 291, in get_MNIST
#     full_train_dataset = FastMNIST(root, train=True, download=True, device=device_hint)
#   File "/auto/users/andsch/github/active_learning_redux/batchbald_redux/fast_mnist.py", line 32, in __init__
#     self.data, self.targets = self.data.to(device), self.targets.to(device)
#   File "/scratch-ssd/andsch/tmp/conda_envs/job-62406/lib/python3.8/site-packages/torch/cuda/__init__.py", line 214, in _lazy_init
#     torch._C._cuda_init()
# RuntimeError: CUDA driver initialization failed, you might not have a CUDA gpu.
#
# experiment_repeated_mnist_job_45_2022-05-12-140856.py caught exception:  Traceback (most recent call last):
#   File "/auto/users/andsch/github/active_learning_redux/batchbald_redux/experiment_repeated_mnist.py", line 302, in <module>
#     config.run(store=store)
#   File "/auto/users/andsch/github/active_learning_redux/batchbald_redux/unified_experiment.py", line 274, in run
#     data = self.load_experiment_data()
#   File "/auto/users/andsch/github/active_learning_redux/batchbald_redux/unified_experiment.py", line 253, in load_experiment_data
#     return self.experiment_data_config.load(self.device)
#   File "/auto/users/andsch/github/active_learning_redux/batchbald_redux/experiment_data.py", line 87, in load
#     return load_standard_experiment_data(
#   File "/auto/users/andsch/github/active_learning_redux/batchbald_redux/experiment_data.py", line 112, in load_standard_experiment_data
#     split_dataset = get_dataset(
#   File "/auto/users/andsch/github/active_learning_redux/batchbald_redux/datasets.py", line 563, in get_dataset
#     split_dataset = dataset_factories[name](
#   File "/auto/users/andsch/github/active_learning_redux/batchbald_redux/datasets.py", line 291, in get_MNIST
#     full_train_dataset = FastMNIST(root, train=True, download=True, device=device_hint)
#   File "/auto/users/andsch/github/active_learning_redux/batchbald_redux/fast_mnist.py", line 32, in __init__
#     self.data, self.targets = self.data.to(device), self.targets.to(device)
#   File "/scratch-ssd/andsch/tmp/conda_envs/job-62419/lib/python3.8/site-packages/torch/cuda/__init__.py", line 214, in _lazy_init
#     torch._C._cuda_init()
# RuntimeError: CUDA driver initialization failed, you might not have a CUDA gpu.

# %%
df.columns
# Out:
# Index(['idx', 'exp_idx', 'cfg_exp_type', 'cfg_seed',
#        'cfg_experiment_data_config_id_dataset_name',
#        'cfg_experiment_data_config_id_repetitions',
#        'cfg_experiment_data_config_initial_training_set_size',
#        'cfg_experiment_data_config_validation_set_size',
#        'cfg_experiment_data_config_validation_split_random_state',
#        'cfg_experiment_data_config_evaluation_set_size',
#        'cfg_experiment_data_config_add_dataset_noise',
#        'cfg_experiment_data_config_ood_dataset_config', 'cfg_acquisition_size',
#        'cfg_max_training_set', 'cfg_max_training_epochs',
#        'cfg_num_pool_samples', 'cfg_num_validation_samples',
#        'cfg_num_training_samples', 'cfg_device', 'cfg_acquisition_function',
#        'cfg_train_eval_model', 'cfg_model_trainer_factory',
#        'cfg_ensemble_size', 'cfg_temperature', 'cfg_coldness',
#        'cfg_stochastic_mode', 'cfg_epig_bootstrap_type',
#        'cfg_epig_bootstrap_factor', 'cfg_epig_dtype',
#        'cfg_disable_training_augmentations', 'cfg_cache_explicit_eval_model',
#        'cfg_resnet18_dropout_head', 'current_training_set_size',
#        'training_accuracy', 'training_crossentropy', 'eval_accuracy',
#        'eval_crossentropy'],
#       dtype='object')

# %%
df.cfg_acquisition_size.unique()
# Out:
# array([40, 10, 20,  5])

# %%
df.cfg_stochastic_mode.unique()
# Out:
# array(['StochasticMode.Softrank', 'StochasticMode.Softmax',
#        'StochasticMode.Power', None, 'StochasticMode.TopK'], dtype=object)

# %%
df.cfg_acquisition_function.unique()
# Out:
# array(['batchbald_redux.acquisition_functions.StochasticBALD',
#        'batchbald_redux.baseline_acquisition_functions.StdDev',
#        'batchbald_redux.acquisition_functions.bald.StochasticBALD',
#        'batchbald_redux.acquisition_functions.Random',
#        'batchbald_redux.baseline_acquisition_functions.Margin',
#        'batchbald_redux.baseline_acquisition_functions.BADGE',
#        'batchbald_redux.baseline_acquisition_functions.VariationRatios',
#        'batchbald_redux.acquisition_functions.BALD',
#        'batchbald_redux.acquisition_functions.BatchBALD'], dtype=object)

# %%
df.to_csv("rmnist_flattened.csv.xz", index=False)

# %%
def get_nice_method_name(row, incl_stoch=True):
    method_name: str = row.cfg_acquisition_function

    prefix = "batchbald_redux.acquisition_functions."
    if method_name.startswith(prefix):
        method_name = method_name[len(prefix) :]

    prefix = "batchbald_redux.baseline_acquisition_functions."
    if method_name.startswith(prefix):
        method_name = method_name[len(prefix) :]

        if row.cfg_stochastic_mode and incl_stoch:
            prefix_length = len("StochasticMode.")
            stochast_mode_type = row.cfg_stochastic_mode[prefix_length:]
            if stochast_mode_type != "TopK":
                method_name = stochast_mode_type + method_name

    if method_name == "StochasticBALD":
        if incl_stoch:
            prefix_length = len("StochasticMode.")
            method_name = row.cfg_stochastic_mode[prefix_length:] + "BALD"
        else:
            method_name = "BALD"

    acquisition_size = row.cfg_acquisition_size
    if acquisition_size != 10:
        method_name = f"{method_name} {acquisition_size}"
    return method_name


df["cfg_method_name"] = df.apply(axis=1, func=get_nice_method_name)
df["cfg_simple_method_name"] = df.apply(axis=1, func=get_nice_method_name, incl_stoch=False)
df.cfg_method_name.unique(), df.cfg_simple_method_name.unique()
# Out:
# (array(['PowerMargin', 'Random', 'BALD 20', 'SoftrankBALD', 'BADGE',
#         'BADGE 20', 'SoftmaxBALD 20', 'SoftrankVariationRatios',
#         'BatchBALD 5', 'SoftmaxBALD', 'SoftrankStdDev', 'PowerBALD 20',
#         'BALD 40', 'BALD', 'PowerBALD', 'PowerBALD 40', 'BADGE 80',
#         'SoftrankBALD 20', 'SoftmaxBALD 40', 'PowerStdDev',
#         'SoftrankBALD 40', 'SoftmaxMargin', 'SoftmaxVariationRatios',
#         'BADGE 40', 'SoftrankMargin', 'SoftmaxStdDev', 'BADGE 160',
#         'Margin', 'VariationRatios', 'PowerVariationRatios', 'StdDev'],
#        dtype=object),
#  array(['Margin', 'Random', 'BALD 20', 'BALD', 'BADGE', 'BADGE 20',
#         'VariationRatios', 'BatchBALD 5', 'StdDev', 'BALD 40', 'BADGE 80',
#         'BADGE 40', 'BADGE 160'], dtype=object))

# %%
def get_nice_stochastic_mode(row):
    prefix_length = len("StochasticMode.")
    nice_stochastic_mode = "TopK"
    if row.cfg_stochastic_mode:
        nice_stochastic_mode = row.cfg_stochastic_mode[prefix_length:]
    return nice_stochastic_mode


df["cfg_nice_stochastic_mode"] = df.apply(axis=1, func=get_nice_stochastic_mode)
df["cfg_nice_stochastic_mode"].unique()
# Out:
# array(['Power', 'TopK', 'Softrank', 'Softmax'], dtype=object)

# %%
sub_df = df[
    (df.cfg_experiment_data_config_id_repetitions == 4)
    & (df.cfg_max_training_set == 300)
    & (
        (
            (
                df.cfg_acquisition_function.str.contains("StdDev")
                | df.cfg_acquisition_function.str.contains("VariationRatios")
                | df.cfg_acquisition_function.str.contains("Margin")
            )
            & (df.cfg_stochastic_mode == "StochasticMode.TopK")
        )
        | df.cfg_acquisition_function.str.contains("Random")
        | (df.cfg_method_name == "BALD")
        | (df.cfg_method_name == "BatchBALD 5")
        | (df.cfg_method_name == "BADGE 40")
    )
]
g = sns.relplot(
    data=sub_df,
    x="current_training_set_size",
    y="eval_accuracy",
    hue="cfg_simple_method_name",
    # col="cfg_simple_method_name",
    kind="line",
)
g.fig.subplots_adjust(top=0.9)  # adjust the Figure in rp
g.fig.suptitle("RepeatedMNIST with different 4 duplications")
# Out:
# Text(0.5, 0.98, 'RepeatedMNIST with different 4 duplications')

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
mpl.rcParams["figure.dpi"] = 150
sns.set_style("whitegrid")

# %%
def savefig(g, path):
    g.savefig(path, transparent=True, dpi=300, bbox_inches="tight", pad_indices=0)

# %%
c = sns.color_palette()
c
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
sub_df = df[
    (df.cfg_experiment_data_config_id_repetitions == 4)
    & (df.cfg_max_training_set == 300)
    & (
        df.cfg_acquisition_function.str.contains("StdDev")
        | df.cfg_acquisition_function.str.contains("VariationRatios")
        # | df.cfg_acquisition_function.str.contains("Margin")
        # | df.cfg_acquisition_function.str.contains("Random")
    )
]
sub_df = sub_df.copy()
sub_df["Scoring Func"] = sub_df["cfg_simple_method_name"]
sub_df["Acq Mode"] = sub_df["cfg_nice_stochastic_mode"]
sub_df["Accuracy"] = sub_df["eval_accuracy"]
sub_df["Training Set Size"] = sub_df["current_training_set_size"]
g = sns.relplot(
    data=sub_df,
    x="Training Set Size",
    y="Accuracy",
    hue="Acq Mode",
    style="Scoring Func",
    hue_order=["Power", "Softmax", "Softrank", "TopK"],
    #palette=[c[1], c[3], c[6], c[5]],
    # col="cfg_simple_method_name",
    kind="line",
)
# g.fig.subplots_adjust(top=0.9)  # adjust the Figure in rp
g.fig.suptitle("RepeatedMNIST (4x MNIST, acq batch size 10, $\\beta=1$)", x=0.4)
g.set_axis_labels(x="Training Set Size", y="Accuracy")
plt.legend(loc="lower right", ncol=2)
g._legend.remove()
savefig(g, "response_rmnist_others.pdf")
# TODO:
#     * strip StochasticMode
#     * move legend to bottom
# Out:
# /home/blackhc/anaconda3/envs/active_learning/lib/python3.8/site-packages/seaborn/axisgrid.py:56: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "pad_indices" which is no longer supported as of 3.3 and will become an error two minor releases later
#   self.fig.savefig(*args, **kwargs)

# %%
sub_df = df[
    (df.cfg_max_training_set == 300)
    & (df.cfg_acquisition_function.str.contains("StdDev") | df.cfg_acquisition_function.str.contains("Random"))
    & ((df.cfg_coldness == 1) | (df.cfg_acquisition_function != "batchbald_redux.acquisition_functions.StochasticBALD"))
]
g = sns.relplot(
    data=sub_df,
    x="current_training_set_size",
    y="eval_accuracy",
    hue="cfg_method_name",
    col="cfg_experiment_data_config_id_repetitions",
    kind="line",
)
g.fig.subplots_adjust(top=0.9)  # adjust the Figure in rp
g.fig.suptitle("RepeatedMNIST with different # of duplication")
# Out:
# Text(0.5, 0.98, 'RepeatedMNIST with different # of duplication')

# %%
sub_df = df[
    (df.cfg_max_training_set == 300)
    & (df.cfg_acquisition_function.str.contains("VariationRatios") | df.cfg_acquisition_function.str.contains("Random"))
    & ((df.cfg_coldness == 1) | (df.cfg_acquisition_function != "batchbald_redux.acquisition_functions.StochasticBALD"))
]
g = sns.relplot(
    data=sub_df,
    x="current_training_set_size",
    y="eval_accuracy",
    hue="cfg_method_name",
    col="cfg_experiment_data_config_id_repetitions",
    kind="line",
)
g.fig.subplots_adjust(top=0.9)  # adjust the Figure in rp
g.fig.suptitle("RepeatedMNIST with different # of duplication")
# Out:
# Text(0.5, 0.98, 'RepeatedMNIST with different # of duplication')

# %%
sub_df = df[
    (df.cfg_max_training_set == 300)
    & (df.cfg_acquisition_function.str.contains("Margin") | df.cfg_acquisition_function.str.contains("Random"))
    & ((df.cfg_coldness == 1) | (df.cfg_acquisition_function != "batchbald_redux.acquisition_functions.StochasticBALD"))
]
g = sns.relplot(
    data=sub_df,
    x="current_training_set_size",
    y="eval_accuracy",
    hue="cfg_method_name",
    col="cfg_experiment_data_config_id_repetitions",
    kind="line",
)
g.fig.subplots_adjust(top=0.9)  # adjust the Figure in rp
g.fig.suptitle("RepeatedMNIST with different # of duplication")
# Out:
# Text(0.5, 0.98, 'RepeatedMNIST with different # of duplication')

# %%
sub_df = df[
    (df.cfg_max_training_set == 300)
    & (df.cfg_acquisition_function.str.contains("BADGE") | df.cfg_acquisition_function.str.contains("Random"))
    & ((df.cfg_coldness == 1) | (df.cfg_acquisition_function != "batchbald_redux.acquisition_functions.StochasticBALD"))
]
g = sns.relplot(
    data=sub_df,
    x="current_training_set_size",
    y="eval_accuracy",
    hue="cfg_method_name",
    col="cfg_experiment_data_config_id_repetitions",
    kind="line",
)
g.fig.subplots_adjust(top=0.9)  # adjust the Figure in rp
g.fig.suptitle("RepeatedMNIST with different # of duplication")
# Out:
# Text(0.5, 0.98, 'RepeatedMNIST with different # of duplication')

# %%
sub_df = df[(df.cfg_max_training_set == 300) & (~df.cfg_stochastic_mode.isna())]
sub_df = sub_df.copy()
sub_df["repetitions"] = sub_df["cfg_experiment_data_config_id_repetitions"]
g = sns.relplot(
    data=sub_df,
    x="current_training_set_size",
    y="eval_accuracy",
    col="cfg_method_name",
    hue="cfg_coldness",
    row="repetitions",
    kind="line",
    palette=sns.color_palette(n_colors=len(sub_df.cfg_coldness.unique())),
)
g.fig.subplots_adjust(top=0.9)  # adjust the Figure in rp
g.fig.suptitle("RepeatedMNIST with different # of duplication")
# Out:
# Text(0.5, 0.98, 'RepeatedMNIST with different # of duplication')

# %%
sub_df = df[
    (df.cfg_max_training_set == 300)
    & (~df.cfg_stochastic_mode.isna())
    & ((df.cfg_coldness == 1) | (df.cfg_method_name != "SoftrankBALD"))
    & ((df.cfg_coldness == 8) | ~(df.cfg_method_name.isin(["SoftmaxBALD", "PowerBALD"])))
]
g = sns.relplot(
    data=sub_df,
    x="current_training_set_size",
    y="eval_accuracy",
    hue="cfg_method_name",
    style="cfg_experiment_data_config_id_repetitions",
    kind="line",
    palette=sns.color_palette(n_colors=3),
)
g.fig.subplots_adjust(top=0.9)  # adjust the Figure in rp
g.fig.suptitle("RepeatedMNIST with different # of duplication")
# Out:
# Text(0.5, 0.98, 'RepeatedMNIST with different # of duplication')

# %%
df.method_name.unique()
# Out:
# array(['Random', 'BADGE', 'BADGE 20', 'SoftmaxBALD', 'BALD', 'PowerBALD',
#        'BADGE 40', 'SoftrankBALD'], dtype=object)

# %%
sub_df = df[
    (df.cfg_max_training_set == 300)
    & (
        df.cfg_method_name.isin(
            ["Random", "BADGE 40", "SoftmaxBALD", "BALD", "PowerBALD", "BADGE 40", "BatchBALD 5", "SoftrankBALD"]
        )
    )
    & ((df.cfg_coldness == 1) | (df.cfg_method_name != "SoftrankBALD"))
    & ((df.cfg_coldness == 8) | ~(df.cfg_method_name.isin(["SoftmaxBALD", "PowerBALD"])))
]
g = sns.relplot(
    data=sub_df,
    x="current_training_set_size",
    y="eval_accuracy",
    hue="cfg_method_name",
    col="cfg_experiment_data_config_id_repetitions",
    kind="line",
)
g.fig.subplots_adjust(top=0.9)  # adjust the Figure in rp
g.fig.suptitle("RepeatedMNIST with different # of duplication")
# Out:
# Text(0.5, 0.98, 'RepeatedMNIST with different # of duplication')

# %%
sub_df = df[
    (df.cfg_max_training_set == 300)
    & (
        df.cfg_method_name.isin(
            [
                "Random",
                "BADGE 40",
                "SoftmaxBALD 40",
                "BALD",
                "BALD 40",
                "PowerBALD 40",
                "BADGE 40",
                "BatchBALD 5",
                "SoftrankBALD 40",
            ]
        )
    )
    & ((df.cfg_coldness == 1) | (df.cfg_method_name != "SoftrankBALD"))
    & ((df.cfg_coldness == 8) | ~(df.cfg_method_name.isin(["SoftmaxBALD", "PowerBALD"])))
]
g = sns.relplot(
    data=sub_df,
    x="current_training_set_size",
    y="eval_accuracy",
    hue="cfg_method_name",
    col="cfg_experiment_data_config_id_repetitions",
    kind="line",
)
g.fig.subplots_adjust(top=0.9)  # adjust the Figure in rp
g.fig.suptitle("RepeatedMNIST with different # of duplication")
# Out:
# Text(0.5, 0.98, 'RepeatedMNIST with different # of duplication')

# %%
df
# Out:
#                                                     idx  \
# 0     experiment_repeated_mnist_job_43_2022-01-17-17...
# 1     experiment_repeated_mnist_job_43_2022-01-17-17...
# 2     experiment_repeated_mnist_job_43_2022-01-17-17...
# 3     experiment_repeated_mnist_job_43_2022-01-17-17...
# 4     experiment_repeated_mnist_job_43_2022-01-17-17...
# ...                                                 ...
# 6765  experiment_repeated_mnist_job_40_2022-01-20-01...
# 6766  experiment_repeated_mnist_job_40_2022-01-20-01...
# 6767  experiment_repeated_mnist_job_40_2022-01-20-01...
# 6768  experiment_repeated_mnist_job_40_2022-01-20-01...
# 6769  experiment_repeated_mnist_job_40_2022-01-20-01...
#
#                                                 exp_idx  cfg_seed  \
# 0     experiment_repeated_mnist_job_43_2022-01-17-17...      8992
# 1     experiment_repeated_mnist_job_43_2022-01-17-17...      8992
# 2     experiment_repeated_mnist_job_43_2022-01-17-17...      8992
# 3     experiment_repeated_mnist_job_43_2022-01-17-17...      8992
# 4     experiment_repeated_mnist_job_43_2022-01-17-17...      8992
# ...                                                 ...       ...
# 6765  experiment_repeated_mnist_job_40_2022-01-20-01...      8987
# 6766  experiment_repeated_mnist_job_40_2022-01-20-01...      8987
# 6767  experiment_repeated_mnist_job_40_2022-01-20-01...      8987
# 6768  experiment_repeated_mnist_job_40_2022-01-20-01...      8987
# 6769  experiment_repeated_mnist_job_40_2022-01-20-01...      8987
#
#      cfg_experiment_data_config_id_dataset_name  \
# 0                                         MNIST
# 1                                         MNIST
# 2                                         MNIST
# 3                                         MNIST
# 4                                         MNIST
# ...                                         ...
# 6765                                      MNIST
# 6766                                      MNIST
# 6767                                      MNIST
# 6768                                      MNIST
# 6769                                      MNIST
#
#       cfg_experiment_data_config_id_repetitions  \
# 0                                             2
# 1                                             2
# 2                                             2
# 3                                             2
# 4                                             2
# ...                                         ...
# 6765                                          1
# 6766                                          1
# 6767                                          1
# 6768                                          1
# 6769                                          1
#
#       cfg_experiment_data_config_initial_training_set_size  \
# 0                                                    20
# 1                                                    20
# 2                                                    20
# 3                                                    20
# 4                                                    20
# ...                                                 ...
# 6765                                                 20
# 6766                                                 20
# 6767                                                 20
# 6768                                                 20
# 6769                                                 20
#
#       cfg_experiment_data_config_validation_set_size  \
# 0                                               4096
# 1                                               4096
# 2                                               4096
# 3                                               4096
# 4                                               4096
# ...                                              ...
# 6765                                            4096
# 6766                                            4096
# 6767                                            4096
# 6768                                            4096
# 6769                                            4096
#
#       cfg_experiment_data_config_validation_split_random_state  \
# 0                                                     0
# 1                                                     0
# 2                                                     0
# 3                                                     0
# 4                                                     0
# ...                                                 ...
# 6765                                                  0
# 6766                                                  0
# 6767                                                  0
# 6768                                                  0
# 6769                                                  0
#
#       cfg_experiment_data_config_evaluation_set_size  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
# ...                                              ...
# 6765                                               0
# 6766                                               0
# 6767                                               0
# 6768                                               0
# 6769                                               0
#
#       cfg_experiment_data_config_add_dataset_noise  ... cfg_epig_dtype  \
# 0                                             True  ...  torch.float64
# 1                                             True  ...  torch.float64
# 2                                             True  ...  torch.float64
# 3                                             True  ...  torch.float64
# 4                                             True  ...  torch.float64
# ...                                            ...  ...            ...
# 6765                                          True  ...  torch.float64
# 6766                                          True  ...  torch.float64
# 6767                                          True  ...  torch.float64
# 6768                                          True  ...  torch.float64
# 6769                                          True  ...  torch.float64
#
#       cfg_disable_training_augmentations  cfg_cache_explicit_eval_model  \
# 0                                  False                          False
# 1                                  False                          False
# 2                                  False                          False
# 3                                  False                          False
# 4                                  False                          False
# ...                                  ...                            ...
# 6765                               False                          False
# 6766                               False                          False
# 6767                               False                          False
# 6768                               False                          False
# 6769                               False                          False
#
#       current_training_set_size  training_accuracy  training_crossentropy  \
# 0                            20           0.701172               0.991472
# 1                            30           0.753174               0.865532
# 2                            40           0.811035               0.646021
# 3                            50           0.760498               0.879318
# 4                            60           0.797363               0.691267
# ...                         ...                ...                    ...
# 6765                        260           0.918213               0.298883
# 6766                        270           0.914062               0.308994
# 6767                        280           0.925049               0.286282
# 6768                        290           0.929199               0.245269
# 6769                        300           0.930420               0.248955
#
#       eval_accuracy eval_crossentropy  method_name cfg_method_name
# 0            0.7307          0.901537       Random          Random
# 1            0.7744          0.817820       Random          Random
# 2            0.8139          0.661755       Random          Random
# 3            0.7767          0.859534       Random          Random
# 4            0.8146          0.688287       Random          Random
# ...             ...               ...          ...             ...
# 6765         0.9209          0.283539  SoftmaxBALD     SoftmaxBALD
# 6766         0.9207          0.278969  SoftmaxBALD     SoftmaxBALD
# 6767         0.9295          0.271917  SoftmaxBALD     SoftmaxBALD
# 6768         0.9333          0.229946  SoftmaxBALD     SoftmaxBALD
# 6769         0.9353          0.232388  SoftmaxBALD     SoftmaxBALD
#
# [6770 rows x 37 columns]
