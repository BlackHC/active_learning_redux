# %% [markdown]
# # Experiment CIFAR-10
# > Can we get better by training on our assumptions?

# %%
# default_exp experiment_cifar10_svhn_ood

# %%
# hide
import blackhc.project.script
# Out:
# Appended /home/blackhc/PycharmProjects/bald-ical/src to paths
# Switched to directory /home/blackhc/PycharmProjects/bald-ical
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Import modules and functions were are going to use.

# %%
# exports

import dataclasses
import traceback

from blackhc.project import is_run_from_ipython
from blackhc.project.experiment import embedded_experiments

from batchbald_redux import acquisition_functions
from batchbald_redux import baseline_acquisition_functions
from batchbald_redux.experiment_data import StandardExperimentDataConfig, OoDDatasetConfig
from batchbald_redux.unified_experiment import UnifiedExperiment

# %%
# exports

configs = [
    UnifiedExperiment(
        experiment_data_config=StandardExperimentDataConfig(id_dataset_name=id_dataset, id_repetitions=1,
                                                                          initial_training_set_size=20,
                                                                          validation_set_size=4000,
                                                                          validation_split_random_state=0,
                                                                          evaluation_set_size=4000,
                                                                          add_dataset_noise=False,
                                                                          ood_dataset_config=OoDDatasetConfig(ood_dataset_name=ood_dataset, ood_repetitions=1, ood_exposure=ood_exposure)
                                                                          ),
        seed=seed + 4658,
        acquisition_function=acquisition_function,
        acquisition_size=acquisition_size,
        num_pool_samples=num_pool_samples,
        max_training_set=450 #15000,
    )
    for seed in range(5)
    for acquisition_function in [
        acquisition_functions.BALD,
        acquisition_functions.EPIG,
        #acquisition_functions.EvalBALD,
    ]
    for acquisition_size in [10]
    for num_pool_samples in [100]
    for ood_exposure in [False, True]
    for id_dataset, ood_dataset in [("CIFAR-10", "SVHN"), ("SVHN", "CIFAR-10")]
]

if not is_run_from_ipython() and __name__ == "__main__":
    for job_id, store in embedded_experiments(__file__, len(configs)):
        config = configs[job_id]
        config.seed += job_id
        print(config)
        store["config"] = dataclasses.asdict(config)
        store["log"] = {}

        try:
            config.run(store=store)
        except Exception:
            store["exception"] = traceback.format_exc()
            raise

# %%
len(configs)
# Out:
# 40

# %%
import prettyprinter
prettyprinter.install_extras({"dataclasses"})
prettyprinter.pprint(configs)
# Out:
# [
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=4658,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='CIFAR-10',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4000,
#             validation_split_random_state=0,
#             evaluation_set_size=4000,
#             add_dataset_noise=False,
#             ood_dataset_config=batchbald_redux.experiment_data.OoDDatasetConfig(
#                 ood_dataset_name='SVHN',
#                 ood_repetitions=1,
#                 ood_exposure=False
#             )
#         ),
#         acquisition_size=10,
#         max_training_set=450
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=4658,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='SVHN',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4000,
#             validation_split_random_state=0,
#             evaluation_set_size=4000,
#             add_dataset_noise=False,
#             ood_dataset_config=batchbald_redux.experiment_data.OoDDatasetConfig(
#                 ood_dataset_name='CIFAR-10',
#                 ood_repetitions=1,
#                 ood_exposure=False
#             )
#         ),
#         acquisition_size=10,
#         max_training_set=450
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=4658,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='CIFAR-10',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4000,
#             validation_split_random_state=0,
#             evaluation_set_size=4000,
#             add_dataset_noise=False,
#             ood_dataset_config=batchbald_redux.experiment_data.OoDDatasetConfig(
#                 ood_dataset_name='SVHN',
#                 ood_repetitions=1,
#                 ood_exposure=True
#             )
#         ),
#         acquisition_size=10,
#         max_training_set=450
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=4658,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='SVHN',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4000,
#             validation_split_random_state=0,
#             evaluation_set_size=4000,
#             add_dataset_noise=False,
#             ood_dataset_config=batchbald_redux.experiment_data.OoDDatasetConfig(
#                 ood_dataset_name='CIFAR-10',
#                 ood_repetitions=1,
#                 ood_exposure=True
#             )
#         ),
#         acquisition_size=10,
#         max_training_set=450
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=4658,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='CIFAR-10',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4000,
#             validation_split_random_state=0,
#             evaluation_set_size=4000,
#             add_dataset_noise=False,
#             ood_dataset_config=batchbald_redux.experiment_data.OoDDatasetConfig(
#                 ood_dataset_name='SVHN',
#                 ood_repetitions=1,
#                 ood_exposure=False
#             )
#         ),
#         acquisition_size=10,
#         max_training_set=450,
#         # class
#         acquisition_function=batchbald_redux.acquisition_functions.EPIG
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=4658,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='SVHN',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4000,
#             validation_split_random_state=0,
#             evaluation_set_size=4000,
#             add_dataset_noise=False,
#             ood_dataset_config=batchbald_redux.experiment_data.OoDDatasetConfig(
#                 ood_dataset_name='CIFAR-10',
#                 ood_repetitions=1,
#                 ood_exposure=False
#             )
#         ),
#         acquisition_size=10,
#         max_training_set=450,
#         # class
#         acquisition_function=batchbald_redux.acquisition_functions.EPIG
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=4658,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='CIFAR-10',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4000,
#             validation_split_random_state=0,
#             evaluation_set_size=4000,
#             add_dataset_noise=False,
#             ood_dataset_config=batchbald_redux.experiment_data.OoDDatasetConfig(
#                 ood_dataset_name='SVHN',
#                 ood_repetitions=1,
#                 ood_exposure=True
#             )
#         ),
#         acquisition_size=10,
#         max_training_set=450,
#         # class
#         acquisition_function=batchbald_redux.acquisition_functions.EPIG
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=4658,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='SVHN',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4000,
#             validation_split_random_state=0,
#             evaluation_set_size=4000,
#             add_dataset_noise=False,
#             ood_dataset_config=batchbald_redux.experiment_data.OoDDatasetConfig(
#                 ood_dataset_name='CIFAR-10',
#                 ood_repetitions=1,
#                 ood_exposure=True
#             )
#         ),
#         acquisition_size=10,
#         max_training_set=450,
#         # class
#         acquisition_function=batchbald_redux.acquisition_functions.EPIG
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=4659,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='CIFAR-10',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4000,
#             validation_split_random_state=0,
#             evaluation_set_size=4000,
#             add_dataset_noise=False,
#             ood_dataset_config=batchbald_redux.experiment_data.OoDDatasetConfig(
#                 ood_dataset_name='SVHN',
#                 ood_repetitions=1,
#                 ood_exposure=False
#             )
#         ),
#         acquisition_size=10,
#         max_training_set=450
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=4659,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='SVHN',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4000,
#             validation_split_random_state=0,
#             evaluation_set_size=4000,
#             add_dataset_noise=False,
#             ood_dataset_config=batchbald_redux.experiment_data.OoDDatasetConfig(
#                 ood_dataset_name='CIFAR-10',
#                 ood_repetitions=1,
#                 ood_exposure=False
#             )
#         ),
#         acquisition_size=10,
#         max_training_set=450
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=4659,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='CIFAR-10',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4000,
#             validation_split_random_state=0,
#             evaluation_set_size=4000,
#             add_dataset_noise=False,
#             ood_dataset_config=batchbald_redux.experiment_data.OoDDatasetConfig(
#                 ood_dataset_name='SVHN',
#                 ood_repetitions=1,
#                 ood_exposure=True
#             )
#         ),
#         acquisition_size=10,
#         max_training_set=450
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=4659,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='SVHN',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4000,
#             validation_split_random_state=0,
#             evaluation_set_size=4000,
#             add_dataset_noise=False,
#             ood_dataset_config=batchbald_redux.experiment_data.OoDDatasetConfig(
#                 ood_dataset_name='CIFAR-10',
#                 ood_repetitions=1,
#                 ood_exposure=True
#             )
#         ),
#         acquisition_size=10,
#         max_training_set=450
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=4659,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='CIFAR-10',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4000,
#             validation_split_random_state=0,
#             evaluation_set_size=4000,
#             add_dataset_noise=False,
#             ood_dataset_config=batchbald_redux.experiment_data.OoDDatasetConfig(
#                 ood_dataset_name='SVHN',
#                 ood_repetitions=1,
#                 ood_exposure=False
#             )
#         ),
#         acquisition_size=10,
#         max_training_set=450,
#         # class
#         acquisition_function=batchbald_redux.acquisition_functions.EPIG
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=4659,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='SVHN',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4000,
#             validation_split_random_state=0,
#             evaluation_set_size=4000,
#             add_dataset_noise=False,
#             ood_dataset_config=batchbald_redux.experiment_data.OoDDatasetConfig(
#                 ood_dataset_name='CIFAR-10',
#                 ood_repetitions=1,
#                 ood_exposure=False
#             )
#         ),
#         acquisition_size=10,
#         max_training_set=450,
#         # class
#         acquisition_function=batchbald_redux.acquisition_functions.EPIG
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=4659,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='CIFAR-10',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4000,
#             validation_split_random_state=0,
#             evaluation_set_size=4000,
#             add_dataset_noise=False,
#             ood_dataset_config=batchbald_redux.experiment_data.OoDDatasetConfig(
#                 ood_dataset_name='SVHN',
#                 ood_repetitions=1,
#                 ood_exposure=True
#             )
#         ),
#         acquisition_size=10,
#         max_training_set=450,
#         # class
#         acquisition_function=batchbald_redux.acquisition_functions.EPIG
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=4659,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='SVHN',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4000,
#             validation_split_random_state=0,
#             evaluation_set_size=4000,
#             add_dataset_noise=False,
#             ood_dataset_config=batchbald_redux.experiment_data.OoDDatasetConfig(
#                 ood_dataset_name='CIFAR-10',
#                 ood_repetitions=1,
#                 ood_exposure=True
#             )
#         ),
#         acquisition_size=10,
#         max_training_set=450,
#         # class
#         acquisition_function=batchbald_redux.acquisition_functions.EPIG
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=4660,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='CIFAR-10',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4000,
#             validation_split_random_state=0,
#             evaluation_set_size=4000,
#             add_dataset_noise=False,
#             ood_dataset_config=batchbald_redux.experiment_data.OoDDatasetConfig(
#                 ood_dataset_name='SVHN',
#                 ood_repetitions=1,
#                 ood_exposure=False
#             )
#         ),
#         acquisition_size=10,
#         max_training_set=450
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=4660,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='SVHN',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4000,
#             validation_split_random_state=0,
#             evaluation_set_size=4000,
#             add_dataset_noise=False,
#             ood_dataset_config=batchbald_redux.experiment_data.OoDDatasetConfig(
#                 ood_dataset_name='CIFAR-10',
#                 ood_repetitions=1,
#                 ood_exposure=False
#             )
#         ),
#         acquisition_size=10,
#         max_training_set=450
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=4660,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='CIFAR-10',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4000,
#             validation_split_random_state=0,
#             evaluation_set_size=4000,
#             add_dataset_noise=False,
#             ood_dataset_config=batchbald_redux.experiment_data.OoDDatasetConfig(
#                 ood_dataset_name='SVHN',
#                 ood_repetitions=1,
#                 ood_exposure=True
#             )
#         ),
#         acquisition_size=10,
#         max_training_set=450
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=4660,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='SVHN',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4000,
#             validation_split_random_state=0,
#             evaluation_set_size=4000,
#             add_dataset_noise=False,
#             ood_dataset_config=batchbald_redux.experiment_data.OoDDatasetConfig(
#                 ood_dataset_name='CIFAR-10',
#                 ood_repetitions=1,
#                 ood_exposure=True
#             )
#         ),
#         acquisition_size=10,
#         max_training_set=450
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=4660,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='CIFAR-10',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4000,
#             validation_split_random_state=0,
#             evaluation_set_size=4000,
#             add_dataset_noise=False,
#             ood_dataset_config=batchbald_redux.experiment_data.OoDDatasetConfig(
#                 ood_dataset_name='SVHN',
#                 ood_repetitions=1,
#                 ood_exposure=False
#             )
#         ),
#         acquisition_size=10,
#         max_training_set=450,
#         # class
#         acquisition_function=batchbald_redux.acquisition_functions.EPIG
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=4660,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='SVHN',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4000,
#             validation_split_random_state=0,
#             evaluation_set_size=4000,
#             add_dataset_noise=False,
#             ood_dataset_config=batchbald_redux.experiment_data.OoDDatasetConfig(
#                 ood_dataset_name='CIFAR-10',
#                 ood_repetitions=1,
#                 ood_exposure=False
#             )
#         ),
#         acquisition_size=10,
#         max_training_set=450,
#         # class
#         acquisition_function=batchbald_redux.acquisition_functions.EPIG
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=4660,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='CIFAR-10',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4000,
#             validation_split_random_state=0,
#             evaluation_set_size=4000,
#             add_dataset_noise=False,
#             ood_dataset_config=batchbald_redux.experiment_data.OoDDatasetConfig(
#                 ood_dataset_name='SVHN',
#                 ood_repetitions=1,
#                 ood_exposure=True
#             )
#         ),
#         acquisition_size=10,
#         max_training_set=450,
#         # class
#         acquisition_function=batchbald_redux.acquisition_functions.EPIG
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=4660,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='SVHN',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4000,
#             validation_split_random_state=0,
#             evaluation_set_size=4000,
#             add_dataset_noise=False,
#             ood_dataset_config=batchbald_redux.experiment_data.OoDDatasetConfig(
#                 ood_dataset_name='CIFAR-10',
#                 ood_repetitions=1,
#                 ood_exposure=True
#             )
#         ),
#         acquisition_size=10,
#         max_training_set=450,
#         # class
#         acquisition_function=batchbald_redux.acquisition_functions.EPIG
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=4661,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='CIFAR-10',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4000,
#             validation_split_random_state=0,
#             evaluation_set_size=4000,
#             add_dataset_noise=False,
#             ood_dataset_config=batchbald_redux.experiment_data.OoDDatasetConfig(
#                 ood_dataset_name='SVHN',
#                 ood_repetitions=1,
#                 ood_exposure=False
#             )
#         ),
#         acquisition_size=10,
#         max_training_set=450
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=4661,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='SVHN',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4000,
#             validation_split_random_state=0,
#             evaluation_set_size=4000,
#             add_dataset_noise=False,
#             ood_dataset_config=batchbald_redux.experiment_data.OoDDatasetConfig(
#                 ood_dataset_name='CIFAR-10',
#                 ood_repetitions=1,
#                 ood_exposure=False
#             )
#         ),
#         acquisition_size=10,
#         max_training_set=450
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=4661,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='CIFAR-10',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4000,
#             validation_split_random_state=0,
#             evaluation_set_size=4000,
#             add_dataset_noise=False,
#             ood_dataset_config=batchbald_redux.experiment_data.OoDDatasetConfig(
#                 ood_dataset_name='SVHN',
#                 ood_repetitions=1,
#                 ood_exposure=True
#             )
#         ),
#         acquisition_size=10,
#         max_training_set=450
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=4661,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='SVHN',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4000,
#             validation_split_random_state=0,
#             evaluation_set_size=4000,
#             add_dataset_noise=False,
#             ood_dataset_config=batchbald_redux.experiment_data.OoDDatasetConfig(
#                 ood_dataset_name='CIFAR-10',
#                 ood_repetitions=1,
#                 ood_exposure=True
#             )
#         ),
#         acquisition_size=10,
#         max_training_set=450
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=4661,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='CIFAR-10',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4000,
#             validation_split_random_state=0,
#             evaluation_set_size=4000,
#             add_dataset_noise=False,
#             ood_dataset_config=batchbald_redux.experiment_data.OoDDatasetConfig(
#                 ood_dataset_name='SVHN',
#                 ood_repetitions=1,
#                 ood_exposure=False
#             )
#         ),
#         acquisition_size=10,
#         max_training_set=450,
#         # class
#         acquisition_function=batchbald_redux.acquisition_functions.EPIG
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=4661,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='SVHN',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4000,
#             validation_split_random_state=0,
#             evaluation_set_size=4000,
#             add_dataset_noise=False,
#             ood_dataset_config=batchbald_redux.experiment_data.OoDDatasetConfig(
#                 ood_dataset_name='CIFAR-10',
#                 ood_repetitions=1,
#                 ood_exposure=False
#             )
#         ),
#         acquisition_size=10,
#         max_training_set=450,
#         # class
#         acquisition_function=batchbald_redux.acquisition_functions.EPIG
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=4661,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='CIFAR-10',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4000,
#             validation_split_random_state=0,
#             evaluation_set_size=4000,
#             add_dataset_noise=False,
#             ood_dataset_config=batchbald_redux.experiment_data.OoDDatasetConfig(
#                 ood_dataset_name='SVHN',
#                 ood_repetitions=1,
#                 ood_exposure=True
#             )
#         ),
#         acquisition_size=10,
#         max_training_set=450,
#         # class
#         acquisition_function=batchbald_redux.acquisition_functions.EPIG
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=4661,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='SVHN',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4000,
#             validation_split_random_state=0,
#             evaluation_set_size=4000,
#             add_dataset_noise=False,
#             ood_dataset_config=batchbald_redux.experiment_data.OoDDatasetConfig(
#                 ood_dataset_name='CIFAR-10',
#                 ood_repetitions=1,
#                 ood_exposure=True
#             )
#         ),
#         acquisition_size=10,
#         max_training_set=450,
#         # class
#         acquisition_function=batchbald_redux.acquisition_functions.EPIG
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=4662,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='CIFAR-10',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4000,
#             validation_split_random_state=0,
#             evaluation_set_size=4000,
#             add_dataset_noise=False,
#             ood_dataset_config=batchbald_redux.experiment_data.OoDDatasetConfig(
#                 ood_dataset_name='SVHN',
#                 ood_repetitions=1,
#                 ood_exposure=False
#             )
#         ),
#         acquisition_size=10,
#         max_training_set=450
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=4662,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='SVHN',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4000,
#             validation_split_random_state=0,
#             evaluation_set_size=4000,
#             add_dataset_noise=False,
#             ood_dataset_config=batchbald_redux.experiment_data.OoDDatasetConfig(
#                 ood_dataset_name='CIFAR-10',
#                 ood_repetitions=1,
#                 ood_exposure=False
#             )
#         ),
#         acquisition_size=10,
#         max_training_set=450
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=4662,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='CIFAR-10',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4000,
#             validation_split_random_state=0,
#             evaluation_set_size=4000,
#             add_dataset_noise=False,
#             ood_dataset_config=batchbald_redux.experiment_data.OoDDatasetConfig(
#                 ood_dataset_name='SVHN',
#                 ood_repetitions=1,
#                 ood_exposure=True
#             )
#         ),
#         acquisition_size=10,
#         max_training_set=450
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=4662,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='SVHN',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4000,
#             validation_split_random_state=0,
#             evaluation_set_size=4000,
#             add_dataset_noise=False,
#             ood_dataset_config=batchbald_redux.experiment_data.OoDDatasetConfig(
#                 ood_dataset_name='CIFAR-10',
#                 ood_repetitions=1,
#                 ood_exposure=True
#             )
#         ),
#         acquisition_size=10,
#         max_training_set=450
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=4662,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='CIFAR-10',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4000,
#             validation_split_random_state=0,
#             evaluation_set_size=4000,
#             add_dataset_noise=False,
#             ood_dataset_config=batchbald_redux.experiment_data.OoDDatasetConfig(
#                 ood_dataset_name='SVHN',
#                 ood_repetitions=1,
#                 ood_exposure=False
#             )
#         ),
#         acquisition_size=10,
#         max_training_set=450,
#         # class
#         acquisition_function=batchbald_redux.acquisition_functions.EPIG
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=4662,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='SVHN',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4000,
#             validation_split_random_state=0,
#             evaluation_set_size=4000,
#             add_dataset_noise=False,
#             ood_dataset_config=batchbald_redux.experiment_data.OoDDatasetConfig(
#                 ood_dataset_name='CIFAR-10',
#                 ood_repetitions=1,
#                 ood_exposure=False
#             )
#         ),
#         acquisition_size=10,
#         max_training_set=450,
#         # class
#         acquisition_function=batchbald_redux.acquisition_functions.EPIG
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=4662,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='CIFAR-10',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4000,
#             validation_split_random_state=0,
#             evaluation_set_size=4000,
#             add_dataset_noise=False,
#             ood_dataset_config=batchbald_redux.experiment_data.OoDDatasetConfig(
#                 ood_dataset_name='SVHN',
#                 ood_repetitions=1,
#                 ood_exposure=True
#             )
#         ),
#         acquisition_size=10,
#         max_training_set=450,
#         # class
#         acquisition_function=batchbald_redux.acquisition_functions.EPIG
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=4662,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='SVHN',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4000,
#             validation_split_random_state=0,
#             evaluation_set_size=4000,
#             add_dataset_noise=False,
#             ood_dataset_config=batchbald_redux.experiment_data.OoDDatasetConfig(
#                 ood_dataset_name='CIFAR-10',
#                 ood_repetitions=1,
#                 ood_exposure=True
#             )
#         ),
#         acquisition_size=10,
#         max_training_set=450,
#         # class
#         acquisition_function=batchbald_redux.acquisition_functions.EPIG
#     )
# ]

# %%
store={}

configs[0].max_training_set=2000
configs[0].experiment_data_config.initial_training_set_size = 400 # int(50000/10*4-1000)
configs[0].max_training_epochs=1
configs[0].num_pool_samples=5
configs[0].run(store)
# Out:
# StandardExperimentDataConfig(id_dataset_name='CIFAR-10', id_repetitions=1, initial_training_set_size=400, validation_set_size=4000, validation_split_random_state=0, evaluation_set_size=4000, add_dataset_noise=False, ood_dataset_config=OoDDatasetConfig(ood_dataset_name='SVHN', ood_repetitions=1, ood_exposure=False))
# Files already downloaded and verified
# /home/blackhc/anaconda3/envs/active_learning/lib/python3.8/site-packages/sklearn/utils/__init__.py:1102: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   return floored.astype(np.int)
# /home/blackhc/anaconda3/envs/active_learning/lib/python3.8/site-packages/sklearn/utils/__init__.py:1102: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   return floored.astype(np.int)
# Files already downloaded and verified
# Using downloaded and verified file: data/SVHN/train_32x32.mat
# Using downloaded and verified file: data/SVHN/test_32x32.mat
# Creating: BALD(
# 	acquisition_size=10,
# 	num_pool_samples=5
# )
# Creating: Cifar10ModelTrainer(
# 	device=cuda,
# 	num_training_samples=1,
# 	num_validation_samples=20,
# 	max_training_epochs=1
# )
# Creating: TrainSelfDistillationEvalModel(
# 	num_pool_samples=5
# )
# Training set size 400:
# Cosine Annealing
# 100%|##########| 1/1 [00:00<?, ?it/s]
# [1/39]   3%|2          [00:00<?]
# Epoch 1 metrics: {'accuracy': 0.21025, 'crossentropy': 2.199812898635864}
# get_predictions_labels:   0%|          | 0/200000 [00:00<?, ?it/s]
# Perf after training {'accuracy': 0.2044, 'crossentropy': tensor(2.1832)}
# get_predictions_labels:   0%|          | 0/574285 [00:00<?, ?it/s]
# Conditional Entropy:   0%|          | 0/114857 [00:00<?, ?it/s]
# Entropy:   0%|          | 0/114857 [00:00<?, ?it/s]
# CandidateBatch(scores=[0.062493302922024485, 0.0560055711224261, 0.05145559099170438, 0.0497398667642992, 0.04560099537457285, 0.04553249766341594, 0.04530527027981113, 0.045267161160822855, 0.044837610777621384, 0.044357130760302566], indices=[2000, 3927, 1522, 111990, 47927, 35721, 19752, 38431, 40195, 20090])
# [('id', 2215), ('id', 4349), ('id', 1684), ('ood', 70390), ('ood', 6327), ('id', 39523), ('id', 21854), ('id', 42496), ('id', 44442), ('id', 22226)]
# Acquiring (label, score)s: 0 (0.06249), 4 (0.05601), 0 (0.05146), -1 (0.04974), -1 (0.0456), 0 (0.04553), 4 (0.04531), 0 (0.04527), 0 (0.04484), 0 (0.04436)
# Training set size 408:
# Cosine Annealing
# 100%|##########| 1/1 [00:00<?, ?it/s]
# [1/39]   3%|2          [00:00<?]
# Epoch 1 metrics: {'accuracy': 0.1875, 'crossentropy': 2.309695158004761}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-c1b6939129d3> in <module>
#       5 configs[0].max_training_epochs=1
#       6 configs[0].num_pool_samples=5
# ----> 7 configs[0].run(store)
#
# ~/PycharmProjects/bald-ical/batchbald_redux/unified_experiment.py in run(self, store)
#     256         )
#     257
# --> 258         active_learner(store)
#     259
#     260 # Cell
#
# ~/PycharmProjects/bald-ical/batchbald_redux/unified_experiment.py in __call__(self, log)
#     109             )
#     110
# --> 111             evaluation_metrics = evaluate(
#     112                 model=trained_model,
#     113                 num_samples=self.num_validation_samples,
#
# ~/PycharmProjects/bald-ical/batchbald_redux/black_box_model_training.py in evaluate(model, loader, num_samples, device, storage_device, loss)
#     506
#     507 def evaluate(*, model: TrainedModel, loader, num_samples, device, storage_device, loss=None):
# --> 508     log_probs_N_K_C, labels_N = model.get_log_probs_N_K_C_labels_N(loader=loader, num_samples=num_samples, device=device, storage_device=storage_device)
#     509
#     510
#
# ~/PycharmProjects/bald-ical/batchbald_redux/trained_model.py in get_log_probs_N_K_C_labels_N(self, loader, num_samples, device, storage_device)
#      50         self, loader: DataLoader, num_samples: int, device: object, storage_device: object
#      51     ):
# ---> 52         log_probs_N_K_C, labels_B = self.model.get_predictions_labels(
#      53             num_samples=num_samples, loader=loader, device=device, storage_device=storage_device
#      54         )
#
# ~/PycharmProjects/bald-ical/batchbald_redux/consistent_mc_dropout.py in get_predictions_labels(self, num_samples, loader, device, storage_device)
#     147         self, *, num_samples: int, loader: data.DataLoader, device, storage_device
#     148     ):
# --> 149         return bmodule_get_predictions_labels(
#     150             self,
#     151             num_samples=num_samples,
#
# ~/anaconda3/envs/active_learning/lib/python3.8/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      24         def decorate_context(*args, **kwargs):
#      25             with self.__class__():
# ---> 26                 return func(*args, **kwargs)
#      27         return cast(F, decorate_context)
#      28
#
# ~/PycharmProjects/bald-ical/batchbald_redux/consistent_mc_dropout.py in bmodule_get_predictions_labels(self, num_samples, loader, device, storage_device)
#     374     self: BayesianModule, *, num_samples: int, loader: data.DataLoader, device, storage_device
#     375 ):
# --> 376     assert_no_shuffling_no_augmentations_dataloader(loader)
#     377
#     378     if num_samples == 0:
#
# ~/PycharmProjects/bald-ical/batchbald_redux/consistent_mc_dropout.py in assert_no_shuffling_no_augmentations_dataloader(dataloader)
#     658     batch_labels_B = None
#     659
# --> 660     for batch_x_A, batch_labels_A in dataloader:
#     661         break
#     662
#
# ~/anaconda3/envs/active_learning/lib/python3.8/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     433         if self._sampler_iter is None:
#     434             self._reset()
# --> 435         data = self._next_data()
#     436         self._num_yielded += 1
#     437         if self._dataset_kind == _DatasetKind.Iterable and \
#
# ~/anaconda3/envs/active_learning/lib/python3.8/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1066
#    1067             assert not self._shutdown and self._tasks_outstanding > 0
# -> 1068             idx, data = self._get_data()
#    1069             self._tasks_outstanding -= 1
#    1070             if self._dataset_kind == _DatasetKind.Iterable:
#
# ~/anaconda3/envs/active_learning/lib/python3.8/site-packages/torch/utils/data/dataloader.py in _get_data(self)
#    1022         elif self._pin_memory:
#    1023             while self._pin_memory_thread.is_alive():
# -> 1024                 success, data = self._try_get_data()
#    1025                 if success:
#    1026                     return data
#
# ~/anaconda3/envs/active_learning/lib/python3.8/site-packages/torch/utils/data/dataloader.py in _try_get_data(self, timeout)
#     870         #   (bool: whether successfully get data, any: data if successful else None)
#     871         try:
# --> 872             data = self._data_queue.get(timeout=timeout)
#     873             return (True, data)
#     874         except Exception as e:
#
# ~/anaconda3/envs/active_learning/lib/python3.8/queue.py in get(self, block, timeout)
#     177                     if remaining <= 0.0:
#     178                         raise Empty
# --> 179                     self.not_empty.wait(remaining)
#     180             item = self._get()
#     181             self.not_full.notify()
#
# ~/anaconda3/envs/active_learning/lib/python3.8/threading.py in wait(self, timeout)
#     304             else:
#     305                 if timeout > 0:
# --> 306                     gotit = waiter.acquire(True, timeout)
#     307                 else:
#     308                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
