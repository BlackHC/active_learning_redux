# %% [markdown]
# # Experiment MNIST: (real EPIG) vs EvalBALD vs BALD
# > Can we get better by training on our assumptions?

# %%
# default_exp experiment_epig_bootstrap_ablation

# %%
# hide
import blackhc.project.script
# Out:
# Appended /home/blackhc/PycharmProjects/bald-ical/src to paths
# Switched to directory /home/blackhc/PycharmProjects/bald-ical
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Import modules and functions were are going to use.

# %%
# exports

import dataclasses
import traceback

from blackhc.project import is_run_from_ipython
from blackhc.project.experiment import embedded_experiments

from batchbald_redux import acquisition_functions
from batchbald_redux import baseline_acquisition_functions
from batchbald_redux.unified_experiment import UnifiedExperiment
from batchbald_redux.experiment_data import StandardExperimentDataConfig

from batchbald_redux.models import MnistModelTrainer

# %%
# exports


configs = [
    UnifiedExperiment(
        experiment_data_config=StandardExperimentDataConfig(
            id_dataset_name="MNIST",
            id_repetitions=id_repetitions,
            initial_training_set_size=20,
            validation_set_size=4096,
            validation_split_random_state=0,
            evaluation_set_size=0,
            add_dataset_noise=id_repetitions > 1,
            ood_dataset_config=None,
        ),
        seed=seed + 8945,
        acquisition_function=acquisition_function,
        acquisition_size=acquisition_size,
        num_pool_samples=num_pool_samples,
        max_training_set=120,
        model_trainer_factory=MnistModelTrainer,
        epig_bootstrap_type=bootstrap_type,
        epig_bootstrap_factor=bootstrap_factor
    )
    for seed in range(5)
    for acquisition_function in [
        acquisition_functions.EPIG,
    ]
    for acquisition_size in [1]
    for num_pool_samples in [100]
    for id_repetitions in [1]
    for (bootstrap_type, bootstrap_factors) in [(acquisition_functions.BootstrapType.SINGLE_BOOTSTRAP, (0.25, 0.5, 0.75)), (acquisition_functions.BootstrapType.PER_POINT_BOOTSTRAP, (0.5, 0.75, 0.9))]
    for bootstrap_factor in bootstrap_factors
]

if not is_run_from_ipython() and __name__ == "__main__":
    for job_id, store in embedded_experiments(__file__, len(configs)):
        config = configs[job_id]
        config.seed += job_id
        print(config)
        store["config"] = dataclasses.asdict(config)
        store["log"] = {}

        try:
            config.run(store=store)
        except Exception:
            store["exception"] = traceback.format_exc()
            raise

# %%
len(configs)
# Out:
# 30

# %%
import prettyprinter
prettyprinter.install_extras({"dataclasses"})
prettyprinter.pprint(configs)
# Out:
# [
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=8945,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='MNIST',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4096,
#             validation_split_random_state=0,
#             evaluation_set_size=0,
#             add_dataset_noise=False,
#             ood_dataset_config=None
#         ),
#         acquisition_size=1,
#         max_training_set=120,
#         # class
#         acquisition_function=batchbald_redux.acquisition_functions.EPIG,
#         # class
#         model_trainer_factory=batchbald_redux.models.MnistModelTrainer,
#         epig_bootstrap_type=batchbald_redux.batchbald.BootstrapType.SINGLE_BOOTSTRAP,
#         epig_bootstrap_factor=0.25
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=8945,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='MNIST',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4096,
#             validation_split_random_state=0,
#             evaluation_set_size=0,
#             add_dataset_noise=False,
#             ood_dataset_config=None
#         ),
#         acquisition_size=1,
#         max_training_set=120,
#         # class
#         acquisition_function=batchbald_redux.acquisition_functions.EPIG,
#         # class
#         model_trainer_factory=batchbald_redux.models.MnistModelTrainer,
#         epig_bootstrap_type=batchbald_redux.batchbald.BootstrapType.SINGLE_BOOTSTRAP,
#         epig_bootstrap_factor=0.5
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=8945,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='MNIST',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4096,
#             validation_split_random_state=0,
#             evaluation_set_size=0,
#             add_dataset_noise=False,
#             ood_dataset_config=None
#         ),
#         acquisition_size=1,
#         max_training_set=120,
#         # class
#         acquisition_function=batchbald_redux.acquisition_functions.EPIG,
#         # class
#         model_trainer_factory=batchbald_redux.models.MnistModelTrainer,
#         epig_bootstrap_type=batchbald_redux.batchbald.BootstrapType.SINGLE_BOOTSTRAP,
#         epig_bootstrap_factor=0.75
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=8945,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='MNIST',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4096,
#             validation_split_random_state=0,
#             evaluation_set_size=0,
#             add_dataset_noise=False,
#             ood_dataset_config=None
#         ),
#         acquisition_size=1,
#         max_training_set=120,
#         # class
#         acquisition_function=batchbald_redux.acquisition_functions.EPIG,
#         # class
#         model_trainer_factory=batchbald_redux.models.MnistModelTrainer,
#         epig_bootstrap_type=batchbald_redux.batchbald.BootstrapType.PER_POINT_BOOTSTRAP,
#         epig_bootstrap_factor=0.5
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=8945,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='MNIST',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4096,
#             validation_split_random_state=0,
#             evaluation_set_size=0,
#             add_dataset_noise=False,
#             ood_dataset_config=None
#         ),
#         acquisition_size=1,
#         max_training_set=120,
#         # class
#         acquisition_function=batchbald_redux.acquisition_functions.EPIG,
#         # class
#         model_trainer_factory=batchbald_redux.models.MnistModelTrainer,
#         epig_bootstrap_type=batchbald_redux.batchbald.BootstrapType.PER_POINT_BOOTSTRAP,
#         epig_bootstrap_factor=0.75
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=8945,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='MNIST',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4096,
#             validation_split_random_state=0,
#             evaluation_set_size=0,
#             add_dataset_noise=False,
#             ood_dataset_config=None
#         ),
#         acquisition_size=1,
#         max_training_set=120,
#         # class
#         acquisition_function=batchbald_redux.acquisition_functions.EPIG,
#         # class
#         model_trainer_factory=batchbald_redux.models.MnistModelTrainer,
#         epig_bootstrap_type=batchbald_redux.batchbald.BootstrapType.PER_POINT_BOOTSTRAP,
#         epig_bootstrap_factor=0.9
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=8946,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='MNIST',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4096,
#             validation_split_random_state=0,
#             evaluation_set_size=0,
#             add_dataset_noise=False,
#             ood_dataset_config=None
#         ),
#         acquisition_size=1,
#         max_training_set=120,
#         # class
#         acquisition_function=batchbald_redux.acquisition_functions.EPIG,
#         # class
#         model_trainer_factory=batchbald_redux.models.MnistModelTrainer,
#         epig_bootstrap_type=batchbald_redux.batchbald.BootstrapType.SINGLE_BOOTSTRAP,
#         epig_bootstrap_factor=0.25
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=8946,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='MNIST',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4096,
#             validation_split_random_state=0,
#             evaluation_set_size=0,
#             add_dataset_noise=False,
#             ood_dataset_config=None
#         ),
#         acquisition_size=1,
#         max_training_set=120,
#         # class
#         acquisition_function=batchbald_redux.acquisition_functions.EPIG,
#         # class
#         model_trainer_factory=batchbald_redux.models.MnistModelTrainer,
#         epig_bootstrap_type=batchbald_redux.batchbald.BootstrapType.SINGLE_BOOTSTRAP,
#         epig_bootstrap_factor=0.5
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=8946,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='MNIST',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4096,
#             validation_split_random_state=0,
#             evaluation_set_size=0,
#             add_dataset_noise=False,
#             ood_dataset_config=None
#         ),
#         acquisition_size=1,
#         max_training_set=120,
#         # class
#         acquisition_function=batchbald_redux.acquisition_functions.EPIG,
#         # class
#         model_trainer_factory=batchbald_redux.models.MnistModelTrainer,
#         epig_bootstrap_type=batchbald_redux.batchbald.BootstrapType.SINGLE_BOOTSTRAP,
#         epig_bootstrap_factor=0.75
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=8946,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='MNIST',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4096,
#             validation_split_random_state=0,
#             evaluation_set_size=0,
#             add_dataset_noise=False,
#             ood_dataset_config=None
#         ),
#         acquisition_size=1,
#         max_training_set=120,
#         # class
#         acquisition_function=batchbald_redux.acquisition_functions.EPIG,
#         # class
#         model_trainer_factory=batchbald_redux.models.MnistModelTrainer,
#         epig_bootstrap_type=batchbald_redux.batchbald.BootstrapType.PER_POINT_BOOTSTRAP,
#         epig_bootstrap_factor=0.5
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=8946,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='MNIST',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4096,
#             validation_split_random_state=0,
#             evaluation_set_size=0,
#             add_dataset_noise=False,
#             ood_dataset_config=None
#         ),
#         acquisition_size=1,
#         max_training_set=120,
#         # class
#         acquisition_function=batchbald_redux.acquisition_functions.EPIG,
#         # class
#         model_trainer_factory=batchbald_redux.models.MnistModelTrainer,
#         epig_bootstrap_type=batchbald_redux.batchbald.BootstrapType.PER_POINT_BOOTSTRAP,
#         epig_bootstrap_factor=0.75
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=8946,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='MNIST',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4096,
#             validation_split_random_state=0,
#             evaluation_set_size=0,
#             add_dataset_noise=False,
#             ood_dataset_config=None
#         ),
#         acquisition_size=1,
#         max_training_set=120,
#         # class
#         acquisition_function=batchbald_redux.acquisition_functions.EPIG,
#         # class
#         model_trainer_factory=batchbald_redux.models.MnistModelTrainer,
#         epig_bootstrap_type=batchbald_redux.batchbald.BootstrapType.PER_POINT_BOOTSTRAP,
#         epig_bootstrap_factor=0.9
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=8947,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='MNIST',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4096,
#             validation_split_random_state=0,
#             evaluation_set_size=0,
#             add_dataset_noise=False,
#             ood_dataset_config=None
#         ),
#         acquisition_size=1,
#         max_training_set=120,
#         # class
#         acquisition_function=batchbald_redux.acquisition_functions.EPIG,
#         # class
#         model_trainer_factory=batchbald_redux.models.MnistModelTrainer,
#         epig_bootstrap_type=batchbald_redux.batchbald.BootstrapType.SINGLE_BOOTSTRAP,
#         epig_bootstrap_factor=0.25
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=8947,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='MNIST',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4096,
#             validation_split_random_state=0,
#             evaluation_set_size=0,
#             add_dataset_noise=False,
#             ood_dataset_config=None
#         ),
#         acquisition_size=1,
#         max_training_set=120,
#         # class
#         acquisition_function=batchbald_redux.acquisition_functions.EPIG,
#         # class
#         model_trainer_factory=batchbald_redux.models.MnistModelTrainer,
#         epig_bootstrap_type=batchbald_redux.batchbald.BootstrapType.SINGLE_BOOTSTRAP,
#         epig_bootstrap_factor=0.5
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=8947,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='MNIST',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4096,
#             validation_split_random_state=0,
#             evaluation_set_size=0,
#             add_dataset_noise=False,
#             ood_dataset_config=None
#         ),
#         acquisition_size=1,
#         max_training_set=120,
#         # class
#         acquisition_function=batchbald_redux.acquisition_functions.EPIG,
#         # class
#         model_trainer_factory=batchbald_redux.models.MnistModelTrainer,
#         epig_bootstrap_type=batchbald_redux.batchbald.BootstrapType.SINGLE_BOOTSTRAP,
#         epig_bootstrap_factor=0.75
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=8947,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='MNIST',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4096,
#             validation_split_random_state=0,
#             evaluation_set_size=0,
#             add_dataset_noise=False,
#             ood_dataset_config=None
#         ),
#         acquisition_size=1,
#         max_training_set=120,
#         # class
#         acquisition_function=batchbald_redux.acquisition_functions.EPIG,
#         # class
#         model_trainer_factory=batchbald_redux.models.MnistModelTrainer,
#         epig_bootstrap_type=batchbald_redux.batchbald.BootstrapType.PER_POINT_BOOTSTRAP,
#         epig_bootstrap_factor=0.5
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=8947,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='MNIST',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4096,
#             validation_split_random_state=0,
#             evaluation_set_size=0,
#             add_dataset_noise=False,
#             ood_dataset_config=None
#         ),
#         acquisition_size=1,
#         max_training_set=120,
#         # class
#         acquisition_function=batchbald_redux.acquisition_functions.EPIG,
#         # class
#         model_trainer_factory=batchbald_redux.models.MnistModelTrainer,
#         epig_bootstrap_type=batchbald_redux.batchbald.BootstrapType.PER_POINT_BOOTSTRAP,
#         epig_bootstrap_factor=0.75
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=8947,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='MNIST',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4096,
#             validation_split_random_state=0,
#             evaluation_set_size=0,
#             add_dataset_noise=False,
#             ood_dataset_config=None
#         ),
#         acquisition_size=1,
#         max_training_set=120,
#         # class
#         acquisition_function=batchbald_redux.acquisition_functions.EPIG,
#         # class
#         model_trainer_factory=batchbald_redux.models.MnistModelTrainer,
#         epig_bootstrap_type=batchbald_redux.batchbald.BootstrapType.PER_POINT_BOOTSTRAP,
#         epig_bootstrap_factor=0.9
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=8948,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='MNIST',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4096,
#             validation_split_random_state=0,
#             evaluation_set_size=0,
#             add_dataset_noise=False,
#             ood_dataset_config=None
#         ),
#         acquisition_size=1,
#         max_training_set=120,
#         # class
#         acquisition_function=batchbald_redux.acquisition_functions.EPIG,
#         # class
#         model_trainer_factory=batchbald_redux.models.MnistModelTrainer,
#         epig_bootstrap_type=batchbald_redux.batchbald.BootstrapType.SINGLE_BOOTSTRAP,
#         epig_bootstrap_factor=0.25
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=8948,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='MNIST',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4096,
#             validation_split_random_state=0,
#             evaluation_set_size=0,
#             add_dataset_noise=False,
#             ood_dataset_config=None
#         ),
#         acquisition_size=1,
#         max_training_set=120,
#         # class
#         acquisition_function=batchbald_redux.acquisition_functions.EPIG,
#         # class
#         model_trainer_factory=batchbald_redux.models.MnistModelTrainer,
#         epig_bootstrap_type=batchbald_redux.batchbald.BootstrapType.SINGLE_BOOTSTRAP,
#         epig_bootstrap_factor=0.5
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=8948,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='MNIST',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4096,
#             validation_split_random_state=0,
#             evaluation_set_size=0,
#             add_dataset_noise=False,
#             ood_dataset_config=None
#         ),
#         acquisition_size=1,
#         max_training_set=120,
#         # class
#         acquisition_function=batchbald_redux.acquisition_functions.EPIG,
#         # class
#         model_trainer_factory=batchbald_redux.models.MnistModelTrainer,
#         epig_bootstrap_type=batchbald_redux.batchbald.BootstrapType.SINGLE_BOOTSTRAP,
#         epig_bootstrap_factor=0.75
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=8948,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='MNIST',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4096,
#             validation_split_random_state=0,
#             evaluation_set_size=0,
#             add_dataset_noise=False,
#             ood_dataset_config=None
#         ),
#         acquisition_size=1,
#         max_training_set=120,
#         # class
#         acquisition_function=batchbald_redux.acquisition_functions.EPIG,
#         # class
#         model_trainer_factory=batchbald_redux.models.MnistModelTrainer,
#         epig_bootstrap_type=batchbald_redux.batchbald.BootstrapType.PER_POINT_BOOTSTRAP,
#         epig_bootstrap_factor=0.5
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=8948,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='MNIST',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4096,
#             validation_split_random_state=0,
#             evaluation_set_size=0,
#             add_dataset_noise=False,
#             ood_dataset_config=None
#         ),
#         acquisition_size=1,
#         max_training_set=120,
#         # class
#         acquisition_function=batchbald_redux.acquisition_functions.EPIG,
#         # class
#         model_trainer_factory=batchbald_redux.models.MnistModelTrainer,
#         epig_bootstrap_type=batchbald_redux.batchbald.BootstrapType.PER_POINT_BOOTSTRAP,
#         epig_bootstrap_factor=0.75
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=8948,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='MNIST',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4096,
#             validation_split_random_state=0,
#             evaluation_set_size=0,
#             add_dataset_noise=False,
#             ood_dataset_config=None
#         ),
#         acquisition_size=1,
#         max_training_set=120,
#         # class
#         acquisition_function=batchbald_redux.acquisition_functions.EPIG,
#         # class
#         model_trainer_factory=batchbald_redux.models.MnistModelTrainer,
#         epig_bootstrap_type=batchbald_redux.batchbald.BootstrapType.PER_POINT_BOOTSTRAP,
#         epig_bootstrap_factor=0.9
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=8949,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='MNIST',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4096,
#             validation_split_random_state=0,
#             evaluation_set_size=0,
#             add_dataset_noise=False,
#             ood_dataset_config=None
#         ),
#         acquisition_size=1,
#         max_training_set=120,
#         # class
#         acquisition_function=batchbald_redux.acquisition_functions.EPIG,
#         # class
#         model_trainer_factory=batchbald_redux.models.MnistModelTrainer,
#         epig_bootstrap_type=batchbald_redux.batchbald.BootstrapType.SINGLE_BOOTSTRAP,
#         epig_bootstrap_factor=0.25
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=8949,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='MNIST',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4096,
#             validation_split_random_state=0,
#             evaluation_set_size=0,
#             add_dataset_noise=False,
#             ood_dataset_config=None
#         ),
#         acquisition_size=1,
#         max_training_set=120,
#         # class
#         acquisition_function=batchbald_redux.acquisition_functions.EPIG,
#         # class
#         model_trainer_factory=batchbald_redux.models.MnistModelTrainer,
#         epig_bootstrap_type=batchbald_redux.batchbald.BootstrapType.SINGLE_BOOTSTRAP,
#         epig_bootstrap_factor=0.5
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=8949,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='MNIST',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4096,
#             validation_split_random_state=0,
#             evaluation_set_size=0,
#             add_dataset_noise=False,
#             ood_dataset_config=None
#         ),
#         acquisition_size=1,
#         max_training_set=120,
#         # class
#         acquisition_function=batchbald_redux.acquisition_functions.EPIG,
#         # class
#         model_trainer_factory=batchbald_redux.models.MnistModelTrainer,
#         epig_bootstrap_type=batchbald_redux.batchbald.BootstrapType.SINGLE_BOOTSTRAP,
#         epig_bootstrap_factor=0.75
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=8949,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='MNIST',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4096,
#             validation_split_random_state=0,
#             evaluation_set_size=0,
#             add_dataset_noise=False,
#             ood_dataset_config=None
#         ),
#         acquisition_size=1,
#         max_training_set=120,
#         # class
#         acquisition_function=batchbald_redux.acquisition_functions.EPIG,
#         # class
#         model_trainer_factory=batchbald_redux.models.MnistModelTrainer,
#         epig_bootstrap_type=batchbald_redux.batchbald.BootstrapType.PER_POINT_BOOTSTRAP,
#         epig_bootstrap_factor=0.5
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=8949,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='MNIST',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4096,
#             validation_split_random_state=0,
#             evaluation_set_size=0,
#             add_dataset_noise=False,
#             ood_dataset_config=None
#         ),
#         acquisition_size=1,
#         max_training_set=120,
#         # class
#         acquisition_function=batchbald_redux.acquisition_functions.EPIG,
#         # class
#         model_trainer_factory=batchbald_redux.models.MnistModelTrainer,
#         epig_bootstrap_type=batchbald_redux.batchbald.BootstrapType.PER_POINT_BOOTSTRAP,
#         epig_bootstrap_factor=0.75
#     ),
#     batchbald_redux.unified_experiment.UnifiedExperiment(
#         seed=8949,
#         experiment_data_config=batchbald_redux.experiment_data.StandardExperimentDataConfig(
#             id_dataset_name='MNIST',
#             id_repetitions=1,
#             initial_training_set_size=20,
#             validation_set_size=4096,
#             validation_split_random_state=0,
#             evaluation_set_size=0,
#             add_dataset_noise=False,
#             ood_dataset_config=None
#         ),
#         acquisition_size=1,
#         max_training_set=120,
#         # class
#         acquisition_function=batchbald_redux.acquisition_functions.EPIG,
#         # class
#         model_trainer_factory=batchbald_redux.models.MnistModelTrainer,
#         epig_bootstrap_type=batchbald_redux.batchbald.BootstrapType.PER_POINT_BOOTSTRAP,
#         epig_bootstrap_factor=0.9
#     )
# ]

# %%
store={}

config = configs[0]

config.max_training_epochs=1
config.num_pool_samples=5
config.experiment_data_config.evaluation_set_size=0
config.run(store)
# Out:
# Creating: EPIG(
# 	acquisition_size=1,
# 	num_pool_samples=5,
# 	epig_bootstrap_type=BootstrapType.SINGLE_BOOTSTRAP,
# 	epig_bootstrap_factor=0.25
# )
# Creating: MnistModelTrainer(
# 	device=cuda,
# 	num_training_samples=1,
# 	num_validation_samples=20,
# 	max_training_epochs=1
# )
# Creating: TrainSelfDistillationEvalModel(
# 	num_pool_samples=5
# )
# Training set size 20:
# /home/blackhc/anaconda3/envs/active_learning/lib/python3.8/site-packages/sklearn/utils/__init__.py:1102: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   return floored.astype(np.int)
# /home/blackhc/anaconda3/envs/active_learning/lib/python3.8/site-packages/sklearn/utils/__init__.py:1102: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   return floored.astype(np.int)
# 100%|##########| 1/1 [00:00<?, ?it/s]
# [1/16]   6%|6          [00:00<?]
# [1/32]   3%|3          [00:00<?]
# Epoch metrics: {'accuracy': 0.588623046875, 'crossentropy': 1.7798746675252914}
# RestoringEarlyStopping: Restoring best parameters. (Score: 0.588623046875)
# RestoringEarlyStopping: Restoring optimizer.
# get_predictions_labels:   0%|          | 0/200000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-c3a3ce2f8dac> in <module>
#       6 config.num_pool_samples=5
#       7 config.experiment_data_config.evaluation_set_size=0
# ----> 8 config.run(store)
#
# ~/PycharmProjects/bald-ical/batchbald_redux/unified_experiment.py in run(self, store)
#     254         )
#     255
# --> 256         active_learner(store)
#     257
#     258 # Cell
#
# ~/PycharmProjects/bald-ical/batchbald_redux/unified_experiment.py in __call__(self, log)
#     109             )
#     110
# --> 111             evaluation_metrics = evaluate(
#     112                 model=trained_model,
#     113                 num_samples=self.num_validation_samples,
#
# ~/PycharmProjects/bald-ical/batchbald_redux/black_box_model_training.py in evaluate(model, loader, num_samples, device, storage_device, loss)
#     506
#     507 def evaluate(*, model: TrainedModel, loader, num_samples, device, storage_device, loss=None):
# --> 508     log_probs_N_K_C, labels_N = model.get_log_probs_N_K_C_labels_N(loader=loader, num_samples=num_samples, device=device, storage_device=storage_device)
#     509
#     510
#
# ~/PycharmProjects/bald-ical/batchbald_redux/trained_model.py in get_log_probs_N_K_C_labels_N(self, loader, num_samples, device, storage_device)
#      50         self, loader: DataLoader, num_samples: int, device: object, storage_device: object
#      51     ):
# ---> 52         log_probs_N_K_C, labels_B = self.model.get_predictions_labels(
#      53             num_samples=num_samples, loader=loader, device=device, storage_device=storage_device
#      54         )
#
# ~/PycharmProjects/bald-ical/batchbald_redux/consistent_mc_dropout.py in get_predictions_labels(self, num_samples, loader, device, storage_device)
#     147         self, *, num_samples: int, loader: data.DataLoader, device, storage_device
#     148     ):
# --> 149         return bmodule_get_predictions_labels(
#     150             self,
#     151             num_samples=num_samples,
#
# ~/anaconda3/envs/active_learning/lib/python3.8/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      24         def decorate_context(*args, **kwargs):
#      25             with self.__class__():
# ---> 26                 return func(*args, **kwargs)
#      27         return cast(F, decorate_context)
#      28
#
# ~/PycharmProjects/bald-ical/batchbald_redux/consistent_mc_dropout.py in bmodule_get_predictions_labels(self, num_samples, loader, device, storage_device)
#     391
#     392     @toma.execute.range(0, num_samples, 128)
# --> 393     def get_prediction_batch(start, end):
#     394         nonlocal predictions
#     395         nonlocal labels
#
# ~/anaconda3/envs/active_learning/lib/python3.8/site-packages/toma/__init__.py in execute_range(func)
#     184
#     185             def execute_range(func):
# --> 186                 return explicit.range(func, start, end, initial_step, toma_cache_type=cache_type, toma_context=context)
#     187
#     188             return execute_range
#
# ~/anaconda3/envs/active_learning/lib/python3.8/site-packages/toma/__init__.py in range(func, start, end, initial_step, toma_context, toma_cache_type, *args, **kwargs)
#     267         while current < end:
#     268             try:
# --> 269                 func(current, min(current + batchsize.get(), end), *args, **kwargs)
#     270                 current += batchsize.get()
#     271                 gc_cuda()
#
# ~/PycharmProjects/bald-ical/batchbald_redux/consistent_mc_dropout.py in get_prediction_batch(start, end)
#     421                 labels = torch.empty(labels_shape, dtype=batch_labels.dtype, device=storage_device)
#     422
# --> 423             predictions[data_start:data_end, start:end].copy_(batch_predictions, non_blocking=True)
#     424             if start == 0:
#     425                 labels[data_start:data_end].copy_(batch_labels, non_blocking=True)
#
# KeyboardInterrupt:
