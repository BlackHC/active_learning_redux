# %% [markdown]
# # EPIG Figure 1

# %%
# !conda install -y -c anaconda scikit-learn
# Out:
# ...
# Solving environment: \
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - conda-forge/linux-64::widgetsnbextension==3.5.1=py38h578d9bd_4
#   - pytorch/linux-64::torchvision==0.8.2=py38_cu110
#   - defaults/linux-64::mkl_random==1.1.1=py38h0573a6f_0
#   - defaults/linux-64::mkl_fft==1.2.0=py38h23d657b_0
#   - defaults/linux-64::jedi==0.17.0=py38_0
#   - pytorch/linux-64::pytorch==1.7.1=py3.8_cuda11.0.221_cudnn8.0.5_0
#   - pytorch/linux-64::ignite==0.4.2=py38_0
#   - pytorch/linux-64::torchaudio==0.7.2=py38
#   - conda-forge/linux-64::matplotlib-base==3.3.3=py38h5c7f4ab_0
#   - conda-forge/noarch::ipywidgets==7.5.1=pyh9f0ad1d_1
#   - conda-forge/linux-64::notebook==6.1.5=py38h578d9bd_0
#   - defaults/linux-64::numpy==1.19.2=py38h54aff64_0
#   - conda-forge/noarch::ipympl==0.5.8=pyh9f0ad1d_0
# done
#
# ## Package Plan ##
#
#   environment location: /home/blackhc/anaconda3/envs/active_learning
#
# ...

# %%
import itertools
import numpy as np

from scipy.stats import multivariate_normal
from scipy.stats import norm

from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, ConstantKernel as C

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
def sample(x, f, noise_f):
    y = f(x)
    stddev_x = noise_f(x)    
    noise = np.random.normal(0, stddev_x)
    y += noise
        
    return y, stddev_x

def sample_and_fit_gp(x, f, noise_f):
    y, stddev_x = sample(x, f, noise_f)    
    gp = fit_gp(x, y, stddev_x)
    
    return gp, y, stddev_x


def fit_gp(x, y, std):
    x = np.asarray(x)
    y = np.asarray(y)
    std = np.asarray(std)
    
    #kernel = C(1.0, (1e-3, 1e3)) * RBF(1, (1e-2, 1e2))
    #kernel = RBF(1, (1e-2, 1e2))
    kernel = RBF(1)
    #kernel = RBF(0.1, (1e-2, 1e2))
    # Instantiate a Gaussian Process model
    gp = GaussianProcessRegressor(kernel=kernel, alpha=std ** 2,
                                  n_restarts_optimizer=10)
    
    # Fit to data using Maximum Likelihood Estimation of the parameters
    gp.fit(x[:, None], y)
    
    return gp

# %%
def plot_stddev(x, y, sigma, axes=None, label='95% confidence interval', color="b"):
    if axes is None:
        axes = plt.gca()
        
    axes.fill(np.concatenate([x, x[::-1]]),
             np.concatenate([
                 y - 1.9600 * sigma,
                 (y + 1.9600 * sigma)[::-1]
             ]),
             alpha=.25,
             fc=color,
             ec='None',
             label=label)

# %%
PLOT_GP_PADDING = 2

def plot_gp(gp, obs_x, obs_y, obs_stddev, padding=None, axes=None, color="b", linewidth=None, traindata_fmt="rx"):
    if padding is None:
        padding = PLOT_GP_PADDING
    if axes is None:
        axes = plt.gca()

    obs_x = np.asarray(obs_x)
    obs_y = np.asarray(obs_y)

    x_min = obs_x.min() - padding
    x_max = obs_x.max() + padding

    axes.set_xlim(x_min, x_max)

    x = np.linspace(x_min, x_max, 1000)
    y, sigma = gp.predict(x[:, None], return_std=True)

    if traindata_fmt:
        axes.errorbar(obs_x,
                     obs_y,
                     obs_stddev,
                     fmt=traindata_fmt,
                     markersize=10,
                     linewidth=2,
                     label=u'Training Data')
    axes.plot(x, y, color, linewidth=linewidth, label=u'Prediction')

    plot_stddev(x, y, sigma, color=color)

    return x, y, sigma

# %%
x = [0]
y = [2]
stddev = 0.05
gp = fit_gp(x, y, stddev)
    
plot_gp(gp, x, y, stddev)

   
plt.show()

# %%
def BALD(gp: GaussianProcessRegressor, x, stddev):
    y_mean, y_stddev = gp.predict([[x]], return_std=True)

    bald_value = norm(scale=y_stddev+stddev).entropy() - norm(scale=stddev).entropy()
    
    return bald_value

# %%
X = np.arange(-3,3, 0.01)
bald_scores = [BALD(gp, x, stddev) for x in X]

# %%
plot_gp(gp, x, y, stddev)
plt.plot(X, bald_scores, c="g", label="BALD")

# %%
def EPIG(gp: GaussianProcessRegressor, x, x_e, stddev):
    Y_mean, cov = gp.predict([[x], [x_e]], return_cov=True)
    
    cov += np.diag([stddev, stddev])
    
    H_Y = norm(scale=cov[0, 0]**0.5).entropy()
    H_Y_e = norm(scale=cov[1, 1]**0.5).entropy()
        
    H_Y__Y_e = multivariate_normal(Y_mean, cov=cov).entropy()
    
    #print(H_Y, H_Y_e, H_Y__Y_e)
    
    epig_value = H_Y + H_Y_e - H_Y__Y_e
    
    return epig_value

# %%
import matplotlib.pyplot as plt
from matplotlib import rc

# MatPlotLib style and settings (that also affect PlotNine)

rc("text", usetex=False)
rc(
    "text.latex",
    preamble=r"""
\usepackage{bbm}
\usepackage{amsmath}
\usepackage{amsfonts}
""",
)

# %%
import seaborn as sns
sns.set_style("whitegrid")
plt.style.use("seaborn-colorblind")
sns.color_palette()
# Out:
# [(0.0, 0.4470588235294118, 0.6980392156862745),
#  (0.0, 0.6196078431372549, 0.45098039215686275),
#  (0.8352941176470589, 0.3686274509803922, 0.0),
#  (0.8, 0.4745098039215686, 0.6549019607843137),
#  (0.9411764705882353, 0.8941176470588236, 0.25882352941176473),
#  (0.33725490196078434, 0.7058823529411765, 0.9137254901960784)]

# %%
def plt_save(grd, output_path, **kwargs):     
    grd.savefig(output_path, transparent=True, bbox_inches="tight", pad_inches=0, dpi=300, **kwargs)

# %%
x_e = 1
epig_scores_single = [EPIG(gp, x, x_e, stddev) for x in X]

plt.figure(figsize=(5*1.6,5))
plot_gp(gp, x, y, stddev)
plt.plot(X, epig_scores_single, c="r", linewidth=2, label="EPIG")
plt.plot(X, bald_scores, c="g", linewidth=2, label="BALD")
#plt.scatter([x_e], [0], c="black", marker="o")

plt.vlines([x_e], ymin=-4, ymax=4, colors="black", label="Evaluation Set")
handles, labels = plt.gca().get_legend_handles_labels()
hl = list(zip(handles, labels))
hl = [hl[2], hl[1], hl[4], hl[5], hl[0], hl[3]]
handles, labels = list(zip(*hl))
#plt.legend(handles, labels, loc='center left', bbox_to_anchor=(1, 0.5))
plt.legend(handles, labels)
plt.xlim([-2, 2])
plt.ylim([-2.5, 3.5])
# Out:
# (-2.5, 3.5)

# %%
import numpy as np
import scipy.stats

# %%
evaluation_distribution = scipy.stats.norm(1, 0.3**2)

# %%
from tqdm import tqdm

# %%
epig_scores = list(tqdm(evaluation_distribution.expect(lambda x_e: EPIG(gp, x, x_e, stddev), epsabs=5e-3) for x in X[::]))
# Out:
# 600it [05:20,  1.87it/s]

# %%
import matplotlib as mpl
mpl.rcParams['hatch.linewidth'] = 0.1  # previous pdf hatch linewidth
mpl.rcParams['hatch.linewidth'] = 2.0  # previous svg hatch linewidth

# %%
fig=plt.figure(figsize=(5*1.6,5))
plot_gp(gp, x, y, stddev, color="C5", linewidth=2, traindata_fmt=None)
plt.scatter(x, y, s=100, c="C0", marker="x", linewidths=2, label="Training Data", zorder=10)

bs = np.array(bald_scores)
plt.plot(X, bs/np.max(bs)*2, c="C1", linewidth=3, label="BALD")

#plt.plot(X, epig_scores_single, c="g", linewidth=2, label="EPIG using a single point")
es = np.array(epig_scores)
plt.plot(X[::], es/np.max(es)*2, c="C2", linewidth=3, label="EPIG")

#plt.vlines([x_e], ymin=-4, ymax=4, colors="black", label="Evaluation Set")
#plt.plot(X, evaluation_distribution.pdf(X), c="black", linewidth=2, label="Test Distribution")
espdf = evaluation_distribution.pdf(X)
plt.fill_between(X, -espdf/np.max(espdf)*2, edgecolor="C3", hatch="||", linewidth=2, facecolor="white", label="Test Distribution", zorder=0)
handles, labels = plt.gca().get_legend_handles_labels()
hl = list(zip(handles, labels))
hl = [hl[2], hl[1], hl[4], hl[5], hl[0], hl[3]]
handles, labels = list(zip(*hl))
#plt.legend(handles, labels, loc='center left', bbox_to_anchor=(1, 0.5))
plt.legend(handles, labels)
plt.xlim([-2, 2])
plt.ylim([-2.5, 3.5])
plt.gca().yaxis.set_ticklabels([])
plt.gca().xaxis.set_ticklabels([])
# Out:
# [Text(-2.0, 0, ''),
#  Text(-1.5, 0, ''),
#  Text(-1.0, 0, ''),
#  Text(-0.5, 0, ''),
#  Text(0.0, 0, ''),
#  Text(0.5, 0, ''),
#  Text(1.0, 0, ''),
#  Text(1.5, 0, ''),
#  Text(2.0, 0, '')]

# %%
plt_save(fig, "plots/EPIG_figure_1.pdf")
